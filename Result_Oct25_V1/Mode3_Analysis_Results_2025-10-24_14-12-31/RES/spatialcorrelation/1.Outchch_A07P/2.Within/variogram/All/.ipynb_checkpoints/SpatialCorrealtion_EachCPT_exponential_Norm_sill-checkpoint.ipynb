# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from skgstat import Variogram
from scipy.interpolate import interp1d
plt.style.use('default')

# --- 1. Settings and initialization ---
DATA_FILE = 'updated_combined_results.csv'
MODEL_NAME = 'exponential'
OUTPUT_BASE_FOLDER = f'variogram_model_fit_simple_{MODEL_NAME}'
INITIAL_BIN_INTERVAL = 0.5
RETRY_ATTEMPTS = 3
BIN_INTERVAL_MULTIPLIER = 2

os.makedirs(OUTPUT_BASE_FOLDER, exist_ok=True)
overall_summary = []

# Load data
try:
    data = pd.read_csv(DATA_FILE)
except FileNotFoundError:
    print(f"Error: Data file '{DATA_FILE}' not found. Please ensure the file exists.")
    exit()

# --- 2. Variogram analysis loop ---
for key, group_df in data.groupby('File Key_1'):
    print(f"\n--- Processing File Key: {key} ---")

    depth_values = group_df['Depth'].values
    values = group_df['withinres'].values

    if len(depth_values) < 10:
        print(f"  Skipping {key}: Not enough data points ({len(depth_values)} < 10).")
        continue

    coordinates = np.vstack([depth_values]).T
    maxlag = max(1, int((np.max(depth_values) - np.min(depth_values)) / 2))
    current_bin_interval = INITIAL_BIN_INTERVAL

    for attempt in range(RETRY_ATTEMPTS):
        try:
            n_lags = max(2, int(maxlag / current_bin_interval))
            V = Variogram(
                coordinates,
                values,
                model=MODEL_NAME,
                maxlag=maxlag,
                n_lags=n_lags,
                normalize=True,  # 순수 계산
                use_nugget=False,
                fit_method='trf',
                fit_sill=True,
                fit_range=True
            )

            # --- Extract data ---
            bins = V.bins
            semivars = V.experimental
            y_fit = V.fitted_model(bins)
            counts = V.bin_count

            # --- Visualize and save ---
            fig = V.plot(show=False)
            fig.suptitle(f'Variogram - {key} ({MODEL_NAME}, bin={current_bin_interval:.2f}m)')
            fig.savefig(os.path.join(OUTPUT_BASE_FOLDER, f'{key}_variogram_bin{current_bin_interval:.2f}m.png'))
            plt.close(fig)

            # Save experimental + fitted
            pd.DataFrame({
                'Lag (m)': bins,
                'Semivariance': semivars,
                'Count': counts,
                'Fitted_Semivariance': y_fit
            }).to_csv(os.path.join(OUTPUT_BASE_FOLDER, f'{key}_variogram_bin{current_bin_interval:.2f}m.csv'), index=False)

            # Interpolated fitted curve
            interp_func = interp1d(bins, y_fit, kind='linear', fill_value='extrapolate')
            lag_dense = np.arange(0, maxlag + 0.1, 0.02)
            fitted_dense = interp_func(lag_dense)
            fitted_dense = np.maximum(fitted_dense, 0)
            fitted_dense[lag_dense == 0] = 0

            pd.DataFrame({
                'Lag (m)': lag_dense,
                'Fitted_Semivariance': fitted_dense
            }).to_csv(os.path.join(OUTPUT_BASE_FOLDER, f'{key}_variogram_fitted_curve_bin{current_bin_interval:.2f}m.csv'), index=False)

            # --- Summarize parameters ---
            desc = V.describe()
            effective_range = desc.get('effective_range', np.nan)
            check_note = np.nan
            if not np.isnan(effective_range) and np.isclose(effective_range, maxlag):
                check_note = 'effective_range_eq_maxlag'

            overall_summary.append({
                'File Key_1': key,
                'nugget': desc.get('nugget', np.nan),
                'sill': desc.get('sill', np.nan),
                'effective_range': effective_range,
                'smoothness': desc.get('smoothness', np.nan),
                'maxlag': maxlag,
                'bin_interval_used': current_bin_interval,
                'Check': check_note
            })

            break  # 성공 시 반복 종료

        except Exception as e:
            print(f"  Failed attempt {attempt+1} for {key} with bin_interval {current_bin_interval:.2f}m: {e}")
            current_bin_interval *= BIN_INTERVAL_MULTIPLIER
            if attempt == RETRY_ATTEMPTS - 1:
                overall_summary.append({
                    'File Key_1': key,
                    'nugget': np.nan,
                    'sill': np.nan,
                    'effective_range': np.nan,
                    'smoothness': np.nan,
                    'maxlag': maxlag,
                    'bin_interval_used': current_bin_interval / BIN_INTERVAL_MULTIPLIER,
                    'Check': 'Failed'
                })

# --- Save final summary ---
pd.DataFrame(overall_summary).to_csv(
    os.path.join(OUTPUT_BASE_FOLDER, 'variogram_parameters_summary.csv'),
    index=False
)

print("\n--- Variogram analysis complete ---")
print(f"Results saved to the '{OUTPUT_BASE_FOLDER}' folder.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
# ----> 5 from skgstat import Variogram
#       6 from scipy.interpolate import interp1d
#       7 plt.style.use('default')
#
# ModuleNotFoundError: No module named 'skgstat'

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from skgstat import Variogram
from scipy.interpolate import interp1d

# --- WLS weighting option ---
# 'default': sigma = sqrt(h^2 / n)
# 'exp': sigma = 1 / sqrt(n * exp(-lag / c))
WLS_OPTION = 'exp'   # 선택: 'default' 또는 'exp'
C_DECAY = 5          # exp 가중치에서 c 값 (상관거리 감쇠 계수)

# --- 1. Settings and initialization ---
DATA_FILE = 'updated_combined_results.csv'
MODEL_NAME = 'exponential'
INITIAL_BIN_INTERVAL = 0.5
OUTPUT_BASE_FOLDER = f'variogram_model_fit_WLS_{MODEL_NAME}_{WLS_OPTION}_{INITIAL_BIN_INTERVAL}'

RETRY_ATTEMPTS = 3
BIN_INTERVAL_MULTIPLIER = 2

os.makedirs(OUTPUT_BASE_FOLDER, exist_ok=True)
overall_summary = []

# Load data
try:
    data = pd.read_csv(DATA_FILE)
except FileNotFoundError:
    print(f"Error: Data file '{DATA_FILE}' not found. Please ensure the file exists.")
    exit()

# --- 2. Variogram analysis loop ---
for key, group_df in data.groupby('File Key_1'):
    print(f"\n--- Processing File Key: {key} ---")

    depth_values = group_df['Depth'].values
    values = group_df['withinres'].values

    if len(depth_values) < 10:
        print(f"  Skipping {key}: Not enough data points ({len(depth_values)} < 10).")
        continue

    coordinates = np.vstack([depth_values]).T
    maxlag = max(1, int((np.max(depth_values) - np.min(depth_values)) / 2))
    current_bin_interval = INITIAL_BIN_INTERVAL

    for attempt in range(RETRY_ATTEMPTS):
        try:
            n_lags = max(2, int(maxlag / current_bin_interval))

            # --- 1. Preliminary variogram to get bin counts ---
            V_tmp = Variogram(
                coordinates,
                values,
                model=MODEL_NAME,
                maxlag=maxlag,
                n_lags=n_lags,
                normalize=True,
                fit_method=None
            )

            bins = V_tmp.bins
            counts = V_tmp.bin_count

            # --- 2. WLS sigma calculation ---
            counts_safe = np.where(counts == 0, np.nan, counts)
            bins_safe = np.where(bins == 0, np.nan, bins)

            if WLS_OPTION == 'default':
                sigma_vals = np.sqrt(bins_safe**2 / counts_safe)
            elif WLS_OPTION == 'exp':
                weights = counts_safe * np.exp(-bins_safe / C_DECAY)
                sigma_vals = 1 / np.sqrt(weights)
            else:
                raise ValueError(f"Unknown WLS_OPTION: {WLS_OPTION}")

            max_sigma = np.nanmax(sigma_vals[~np.isnan(sigma_vals)]) if np.any(~np.isnan(sigma_vals)) else 1.0
            sigma_vals = np.nan_to_num(sigma_vals, nan=max_sigma)
            min_range_bound = current_bin_interval
            max_range_bound = maxlag - current_bin_interval
            sill_min = 0.01
            sill_max = 10
            fit_bounds = ([min_range_bound, sill_min], [max_range_bound, sill_max])

            # --- 3. Final WLS variogram fitting ---
            V = Variogram(
                coordinates,
                values,
                model=MODEL_NAME,
                maxlag=maxlag,
                n_lags=n_lags,
                normalize=True,
                use_nugget=False,
                fit_method='trf',
                fit_sill=True,
                fit_range=True,
                fit_bounds=fit_bounds,
                fit_sigma=sigma_vals
            )

            # --- Extract data ---
            semivars = V.experimental
            y_fit = V.fitted_model(bins)
            counts = V.bin_count

            # --- Visualize and save ---
            fig = V.plot(show=True)
            fig.suptitle(f'Variogram - {key} ({MODEL_NAME} WLS-{WLS_OPTION}, bin={current_bin_interval:.2f}m)')
            fig.savefig(os.path.join(OUTPUT_BASE_FOLDER, f'{key}_variogram_WLS_{WLS_OPTION}_bin{current_bin_interval:.2f}m.png'))
            plt.close(fig)

            pd.DataFrame({
                'Lag (m)': bins,
                'Semivariance': semivars,
                'Count': counts,
                'Fitted_Semivariance': y_fit
            }).to_csv(os.path.join(OUTPUT_BASE_FOLDER, f'{key}_variogram_WLS_{WLS_OPTION}_bin{current_bin_interval:.2f}m.csv'), index=False)

            # Interpolated fitted curve
            interp_func = interp1d(bins, y_fit, kind='linear', fill_value='extrapolate')
            lag_dense = np.arange(0, maxlag + 0.1, 0.02)
            fitted_dense = interp_func(lag_dense)
            fitted_dense = np.maximum(fitted_dense, 0)
            fitted_dense[lag_dense == 0] = 0

            pd.DataFrame({
                'Lag (m)': lag_dense,
                'Fitted_Semivariance': fitted_dense
            }).to_csv(os.path.join(OUTPUT_BASE_FOLDER, f'{key}_variogram_fitted_curve_WLS_{WLS_OPTION}_bin{current_bin_interval:.2f}m.csv'), index=False)

            # --- Summarize parameters ---
            desc = V.describe()
            print(desc)
            effective_range = desc.get('effective_range', np.nan)
            check_note = np.nan
            if not np.isnan(effective_range) and np.isclose(effective_range, maxlag):
                check_note = 'effective_range_eq_maxlag'

            # --- Normalize by maximum experimental semivariance ---
            max_gamma = np.max(semivars)
            nugget_normalized = desc.get('nugget', np.nan) / max_gamma if max_gamma > 0 else np.nan
            sill_normalized = desc.get('sill', np.nan) / max_gamma if max_gamma > 0 else np.nan

            overall_summary.append({
                'File Key_1': key,
                'nugget': desc.get('nugget', np.nan),
                'sill': desc.get('sill', np.nan),
                'effective_range': effective_range,
                'smoothness': desc.get('smoothness', np.nan),
                'nugget_normalized': nugget_normalized,
                'sill_normalized': sill_normalized,
                'maxlag': maxlag,
                'bin_interval_used': current_bin_interval,
                'WLS_option': WLS_OPTION,
                'Check': check_note
            })

            break  # Exit loop on successful fit

        except Exception as e:
            print(f"  Failed attempt {attempt+1} for {key} with bin_interval {current_bin_interval:.2f}m: {e}")
            current_bin_interval *= BIN_INTERVAL_MULTIPLIER
            if attempt == RETRY_ATTEMPTS - 1:
                overall_summary.append({
                    'File Key_1': key,
                    'nugget': np.nan,
                    'sill': np.nan,
                    'effective_range': np.nan,
                    'smoothness': np.nan,
                    'nugget_normalized': np.nan,
                    'sill_normalized': np.nan,
                    'maxlag': maxlag,
                    'bin_interval_used': current_bin_interval / BIN_INTERVAL_MULTIPLIER,
                    'WLS_option': WLS_OPTION,
                    'Check': 'Failed'
                })

# --- Save final summary ---
pd.DataFrame(overall_summary).to_csv(
    os.path.join(OUTPUT_BASE_FOLDER, f'variogram_parameters_summary_WLS_{WLS_OPTION}.csv'),
    index=False
)

print("\n--- Variogram analysis complete ---")
print(f"Results saved to the '{OUTPUT_BASE_FOLDER}' folder with WLS option '{WLS_OPTION}'.")
# Out:
# --- Processing File Key: 66983 ---
# UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 42.01325967658431, 'normalized_sill': 0.0289668161508794, 'normalized_nugget': 0, 'effective_range': 4.668139964064924, 'sill': 0.1613510945310133, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00346624, 0.00365612, 0.00389765, 0.00415623, 0.00443493,
#        0.00473256, 0.00505333, 0.00539946, 0.00577456, 0.00617317,
#        0.00660648, 0.00707487, 0.00758162, 0.00813115, 0.00872776,
#        0.00937745, 0.01009924, 0.0108574 ]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 66984 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 27.403527004227122, 'normalized_sill': 0.06534556977711033, 'normalized_nugget': 0, 'effective_range': 3.0448363338030138, 'sill': 0.2210095778053851, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00351334, 0.00370719, 0.00395367, 0.00421773, 0.00450258,
#        0.004807  , 0.00513579, 0.00549011, 0.00587498, 0.00628428,
#        0.00672982, 0.00721209, 0.00773459, 0.00830211, 0.00891932,
#        0.00959276, 0.01034301, 0.01113193]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 92524 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 57.23150588353252, 'normalized_sill': 0.008771784525961565, 'normalized_nugget': 0, 'effective_range': 6.359056209281391, 'sill': 0.08730226302934638, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00342098, 0.00360711, 0.00384395, 0.00409735, 0.00437024,
#        0.00466148, 0.00497508, 0.00531275, 0.00567912, 0.00606775,
#        0.00648967, 0.0069452 , 0.00743738, 0.00797034, 0.00854804,
#        0.00917603, 0.00987193, 0.01060223]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 92525 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 14.848738776467405, 'normalized_sill': 0.0014961851150562303, 'normalized_nugget': 0, 'effective_range': 1.4848738776467405, 'sill': 0.03628174750075143, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00333554, 0.00351472, 0.00374289, 0.00398673, 0.00424892,
#        0.00452843, 0.00482891, 0.00515192, 0.00550122, 0.00587172,
#        0.00627352, 0.0067059 , 0.007172  , 0.00767541, 0.00821958,
#        0.00880928, 0.00945986, 0.01014159, 0.01089563, 0.01171728]), 'use_nugget': False, 'maxlag': 10, 'n_lags': 20, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [9.5, 10])}}
#
# --- Processing File Key: 92526 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 45.49999999999999, 'normalized_sill': 0.012433725194461532, 'normalized_nugget': 0, 'effective_range': 6.499999999999999, 'sill': 0.08208267007275297, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00397599, 0.00421193, 0.00451052, 0.00483372, 0.00518482,
#        0.00556497, 0.00597869, 0.0064295 , 0.00692582, 0.00746104,
#        0.00805241, 0.00870334, 0.00942177, 0.01021999]), 'use_nugget': False, 'maxlag': 7, 'n_lags': 14, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [6.5, 10])}}
#
# --- Processing File Key: 92527 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 22.44542151142503, 'normalized_sill': 0.01602845569070244, 'normalized_nugget': 0, 'effective_range': 2.49393572349167, 'sill': 0.11814874443069902, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00356267, 0.00376046, 0.00401203, 0.00428204, 0.00457325,
#        0.00488506, 0.00522235, 0.00558548, 0.00598039, 0.00640161,
#        0.00686035, 0.00735761, 0.00789721, 0.00848432, 0.00912492,
#        0.00982361, 0.01060424, 0.0114284 ]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 92534 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 94.35882474750107, 'normalized_sill': 0.007814402487079009, 'normalized_nugget': 0, 'effective_range': 7.258371134423159, 'sill': 0.07842505252250011, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00293467, 0.00308702, 0.00327759, 0.00348036, 0.00369119,
#        0.00390871, 0.00415225, 0.00441262, 0.00469174, 0.00498718,
#        0.00530389, 0.00564221, 0.00600377, 0.00639055, 0.00680475,
#        0.00724786, 0.00772847, 0.00823162, 0.00877698, 0.00935234,
#        0.0099927 , 0.01066938, 0.01139756, 0.01218189, 0.01299899,
#        0.01389666]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 92535 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 26.42125021448812, 'normalized_sill': 0.024804278127671928, 'normalized_nugget': 0, 'effective_range': 2.032403862652932, 'sill': 0.14392771153418651, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00297899, 0.00313775, 0.00333162, 0.00352905, 0.00374328,
#        0.0039824 , 0.00423176, 0.00448485, 0.00475589, 0.00505707,
#        0.00537676, 0.00572092, 0.00608962, 0.00648462, 0.00690721,
#        0.00735995, 0.00785085, 0.00836624, 0.00892527, 0.00952576,
#        0.01017151, 0.0108667 , 0.01161516, 0.01242253, 0.01329493,
#        0.01423749]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 92536 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 19.140996484529587, 'normalized_sill': 0.03489028922086469, 'normalized_nugget': 0, 'effective_range': 2.7344280692185126, 'sill': 0.15734453250242159, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.0039081 , 0.00413713, 0.00442788, 0.00474178, 0.00508203,
#        0.00545038, 0.0058503 , 0.00628523, 0.00676254, 0.00727708,
#        0.00784358, 0.00846527, 0.0091502 , 0.00990603]), 'use_nugget': False, 'maxlag': 7, 'n_lags': 14, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [6.5, 10])}}
#
# --- Processing File Key: 92537 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 92.34975657413285, 'normalized_sill': 0.0036054496250844258, 'normalized_nugget': 0, 'effective_range': 6.596411183866633, 'sill': 0.05309816777306177, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00282447, 0.00296565, 0.00314636, 0.00333835, 0.00354323,
#        0.00376043, 0.00399209, 0.00423908, 0.0045035 , 0.00478256,
#        0.0050815 , 0.00540037, 0.00574053, 0.00610377, 0.0064917 ,
#        0.00690652, 0.00735531, 0.00782381, 0.00833099, 0.00887404,
#        0.00945584, 0.01007956, 0.01074868, 0.01146703, 0.01223853,
#        0.01306843, 0.01396271, 0.01492507]), 'use_nugget': False, 'maxlag': 14, 'n_lags': 28, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [13.5, 10])}}
#
# --- Processing File Key: 92538 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 59.37858287925492, 'normalized_sill': 0.002100690237144025, 'normalized_nugget': 0, 'effective_range': 4.94821523993791, 'sill': 0.03972476588551683, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00298755, 0.00314024, 0.00333507, 0.00354274, 0.00376447,
#        0.00400059, 0.00425265, 0.00452174, 0.00481048, 0.00511633,
#        0.00544459, 0.00579567, 0.00617124, 0.00657384, 0.00700483,
#        0.00746687, 0.00796882, 0.00849499, 0.00906675, 0.00968157,
#        0.01034329, 0.01105617, 0.01182595, 0.01265608]), 'use_nugget': False, 'maxlag': 12, 'n_lags': 24, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [11.5, 10])}}
#
# --- Processing File Key: 92539 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 27.60481995361466, 'normalized_sill': 0.005169173048240347, 'normalized_nugget': 0, 'effective_range': 3.4506024942018323, 'sill': 0.06759925900069937, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00361362, 0.00381609, 0.00407335, 0.00434938, 0.00464809,
#        0.00496745, 0.0053127 , 0.005686  , 0.00609261, 0.00652576,
#        0.00699877, 0.00751231, 0.00807053, 0.00867908, 0.0093436 ,
#        0.01007197]), 'use_nugget': False, 'maxlag': 8, 'n_lags': 16, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [7.5, 10])}}
#
# --- Processing File Key: 92540 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 11.778318168563406, 'normalized_sill': 0.0021229316895667242, 'normalized_nugget': 0, 'effective_range': 1.6826168812233435, 'sill': 0.03979371004080884, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00412787, 0.00442267, 0.00477309, 0.00512629, 0.00547764,
#        0.00580371, 0.00617792, 0.00663985, 0.00713636, 0.00767661,
#        0.0082836 , 0.00896812, 0.00972782, 0.0105731 ]), 'use_nugget': False, 'maxlag': 7, 'n_lags': 14, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [6.5, 10])}}
#
# --- Processing File Key: 92541 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 59.99999999999999, 'normalized_sill': 0.013620959964859, 'normalized_nugget': 0, 'effective_range': 7.499999999999999, 'sill': 0.1041010590840375, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00384681, 0.00410575, 0.00441485, 0.00472738, 0.00507298,
#        0.00545061, 0.00585463, 0.00624375, 0.00660145, 0.00701336,
#        0.00753012, 0.00808108, 0.0086863 , 0.00936022, 0.01011715,
#        0.01095449]), 'use_nugget': False, 'maxlag': 8, 'n_lags': 16, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [7.5, 10])}}
#
# --- Processing File Key: 92542 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 59.133491801151294, 'normalized_sill': 0.009193160660072565, 'normalized_nugget': 0, 'effective_range': 4.548730138550099, 'sill': 0.09058372946652159, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00290265, 0.00304913, 0.00323656, 0.00343599, 0.00364887,
#        0.00387489, 0.00411628, 0.00437357, 0.00464937, 0.00494101,
#        0.00525366, 0.00558756, 0.00594421, 0.00632558, 0.00673381,
#        0.00717033, 0.00764366, 0.00813872, 0.00867556, 0.00925148,
#        0.00986977, 0.01053406, 0.01124838, 0.01201719, 0.01284613,
#        0.01373941]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 92543 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 55.03415103039007, 'normalized_sill': 0.0059505936991859675, 'normalized_nugget': 0, 'effective_range': 6.114905670043341, 'sill': 0.06978662054713677, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00351334, 0.00370719, 0.00395367, 0.00421773, 0.00450258,
#        0.004807  , 0.00513579, 0.00549011, 0.00587498, 0.00628428,
#        0.00672982, 0.00721209, 0.00773459, 0.00830211, 0.00891932,
#        0.00959276, 0.01034301, 0.01113193]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 92544 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 15.844515315216757, 'normalized_sill': 0.06817432321355262, 'normalized_nugget': 0, 'effective_range': 2.263502187888108, 'sill': 0.22643115234371725, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00481006, 0.00531763, 0.00584545, 0.00636139, 0.00694972,
#        0.007802  , 0.00862181, 0.00949533, 0.01014967, 0.01089292,
#        0.01187215, 0.01275082, 0.01331104, 0.01377474]), 'use_nugget': False, 'maxlag': 7, 'n_lags': 14, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [6.5, 10])}}
#
# --- Processing File Key: 92545 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 38.28992451019141, 'normalized_sill': 0.03148284754705145, 'normalized_nugget': 0, 'effective_range': 3.8289924510191415, 'sill': 0.1534669948527121, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00333554, 0.00351472, 0.00374289, 0.00398673, 0.00424892,
#        0.00452843, 0.00482891, 0.00515192, 0.00550122, 0.00587172,
#        0.00627352, 0.0067059 , 0.007172  , 0.00767541, 0.00821958,
#        0.00880928, 0.00945986, 0.01014159, 0.01089563, 0.01171728]), 'use_nugget': False, 'maxlag': 10, 'n_lags': 20, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [9.5, 10])}}
#
# --- Processing File Key: 92546 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 67.47779246847621, 'normalized_sill': 0.011894033047512126, 'normalized_nugget': 0, 'effective_range': 5.6231493723730175, 'sill': 0.09672748232463255, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00304833, 0.00320544, 0.00340605, 0.00361969, 0.00384837,
#        0.00409133, 0.00435127, 0.00462931, 0.00492817, 0.00524414,
#        0.00558408, 0.00594807, 0.00633788, 0.00675592, 0.00720439,
#        0.00768631, 0.00821151, 0.00876025, 0.00935973, 0.01000485,
#        0.01070056, 0.01145169, 0.01226365, 0.01314251]), 'use_nugget': False, 'maxlag': 12, 'n_lags': 24, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [11.5, 10])}}
#
# --- Processing File Key: 92547 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 84.22165616051763, 'normalized_sill': 0.00957157831187525, 'normalized_nugget': 0, 'effective_range': 6.478588935424432, 'sill': 0.08209285541425691, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00287591, 0.00302066, 0.00320561, 0.0034025 , 0.00361242,
#        0.00383568, 0.00407366, 0.00432733, 0.004599  , 0.00488646,
#        0.00519434, 0.00552302, 0.00587393, 0.00624928, 0.00665023,
#        0.00707906, 0.00754328, 0.00802956, 0.008556  , 0.00912036,
#        0.00972581, 0.0103758 , 0.01107416, 0.0118251 , 0.01263299,
#        0.01350367]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 92548 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 8.29639981787639, 'normalized_sill': 0.003718356521750051, 'normalized_nugget': 0, 'effective_range': 1.1851999739823413, 'sill': 0.054953161913625904, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00481006, 0.00531763, 0.00584545, 0.00636139, 0.00694972,
#        0.007802  , 0.00862181, 0.00949533, 0.01014967, 0.01089292,
#        0.01187215, 0.01275082, 0.01331104, 0.01377474]), 'use_nugget': False, 'maxlag': 7, 'n_lags': 14, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [6.5, 10])}}
#
# --- Processing File Key: 92549 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 26.24275025620335, 'normalized_sill': 0.011886647255879212, 'normalized_nugget': 0, 'effective_range': 2.624275025620335, 'sill': 0.0982434052234954, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00329534, 0.00347111, 0.00369515, 0.00393467, 0.0041918 ,
#        0.00446604, 0.00476077, 0.00507679, 0.00541819, 0.00578079,
#        0.00617277, 0.00659465, 0.00704953, 0.00753971, 0.00806952,
#        0.00864166, 0.00927155, 0.0099327 , 0.01066156, 0.01145426]), 'use_nugget': False, 'maxlag': 10, 'n_lags': 20, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [9.5, 10])}}
#
# --- Processing File Key: 92554 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 20.23383702033086, 'normalized_sill': 0.006428018778223719, 'normalized_nugget': 0, 'effective_range': 2.5292296275413575, 'sill': 0.07142161698788936, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00361387, 0.00381636, 0.0040732 , 0.00434938, 0.00464717,
#        0.00496725, 0.00531307, 0.005686  , 0.00609188, 0.00652576,
#        0.00699877, 0.00751231, 0.00807053, 0.00867989, 0.00934451,
#        0.01007197]), 'use_nugget': False, 'maxlag': 8, 'n_lags': 16, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [7.5, 10])}}
#
# --- Processing File Key: 92555 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 94.2193325613502, 'normalized_sill': 0.0017021274661552141, 'normalized_nugget': 0, 'effective_range': 7.247640966257708, 'sill': 0.03435660973975688, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00293014, 0.00307871, 0.00326842, 0.0034705 , 0.00368609,
#        0.00391553, 0.00416027, 0.00442133, 0.00470117, 0.00499743,
#        0.00531505, 0.00565442, 0.00601708, 0.0064054 , 0.00682063,
#        0.00726522, 0.0077473 , 0.00825245, 0.00880028, 0.00938841,
#        0.01002031, 0.01069979, 0.0114311 , 0.01221895, 0.01306933,
#        0.01398672]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 92556 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 137.99999999999997, 'normalized_sill': 0.003396447838238757, 'normalized_nugget': 0, 'effective_range': 11.499999999999998, 'sill': 0.046080726679987, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00298755, 0.00314024, 0.00333507, 0.00354274, 0.00376447,
#        0.00400059, 0.00425265, 0.00452174, 0.00481048, 0.00511633,
#        0.00544459, 0.00579567, 0.00617124, 0.00657384, 0.00700483,
#        0.00746687, 0.00796882, 0.00849499, 0.00906675, 0.00968157,
#        0.01034329, 0.01105617, 0.01182595, 0.01265608]), 'use_nugget': False, 'maxlag': 12, 'n_lags': 24, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [11.5, 10])}}
#
# --- Processing File Key: 92557 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 162.49999999999997, 'normalized_sill': 0.0023467000818538416, 'normalized_nugget': 0, 'effective_range': 12.499999999999998, 'sill': 0.04087384483697057, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00295857, 0.00310902, 0.00330124, 0.00350606, 0.00372457,
#        0.00395737, 0.0042057 , 0.00447069, 0.00475475, 0.00505583,
#        0.00537865, 0.00572374, 0.00609301, 0.00648798, 0.00691089,
#        0.00736397, 0.00785528, 0.00837108, 0.00893053, 0.00953161,
#        0.01017796, 0.0108736 , 0.01162303, 0.01243123, 0.01330458,
#        0.0142479 ]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 94658 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 52.633750789401354, 'normalized_sill': 0.002686562140028683, 'normalized_nugget': 0, 'effective_range': 6.579218848675169, 'sill': 0.050615577471485915, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00366762, 0.00387455, 0.00413726, 0.00442001, 0.00472499,
#        0.00505352, 0.00540869, 0.00579215, 0.00620983, 0.00665744,
#        0.00714593, 0.0076772 , 0.00825656, 0.00888877, 0.00958076,
#        0.01034017]), 'use_nugget': False, 'maxlag': 8, 'n_lags': 16, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [7.5, 10])}}
#
# --- Processing File Key: 100703 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 27.753357994388313, 'normalized_sill': 0.0016909424213398716, 'normalized_nugget': 0, 'effective_range': 2.3127798328656928, 'sill': 0.038710275498028524, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00304833, 0.00320544, 0.00340605, 0.00361969, 0.00384837,
#        0.00409133, 0.00435127, 0.00462931, 0.00492817, 0.00524414,
#        0.00558408, 0.00594807, 0.00633788, 0.00675592, 0.00720439,
#        0.00768631, 0.00821151, 0.00876025, 0.00935973, 0.01000485,
#        0.01070056, 0.01145169, 0.01226365, 0.01314251]), 'use_nugget': False, 'maxlag': 12, 'n_lags': 24, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [11.5, 10])}}
#
# --- Processing File Key: 114319 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 14.811824500105109, 'normalized_sill': 0.000654616749290072, 'normalized_nugget': 0, 'effective_range': 1.6457582777894566, 'sill': 0.01980632312854678, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00346647, 0.00365612, 0.00389752, 0.00415623, 0.00443477,
#        0.00473256, 0.00505365, 0.00539903, 0.00577417, 0.00617317,
#        0.00660648, 0.00707487, 0.00758162, 0.00813115, 0.00872851,
#        0.00937745, 0.0100983 , 0.0108574 ]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 114322 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 61.766351878281206, 'normalized_sill': 0.0017075595637355205, 'normalized_nugget': 0, 'effective_range': 6.86292798647569, 'sill': 0.039210266909829025, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00346647, 0.00365612, 0.00389752, 0.00415623, 0.00443477,
#        0.00473256, 0.00505365, 0.00539903, 0.00577417, 0.00617317,
#        0.00660648, 0.00707487, 0.00758162, 0.00813115, 0.00872851,
#        0.00937745, 0.0100983 , 0.0108574 ]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 122141 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 19.697494728928397, 'normalized_sill': 0.0022987867508248647, 'normalized_nugget': 0, 'effective_range': 1.7906813389934908, 'sill': 0.03939109658909301, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00321877, 0.00338855, 0.00360511, 0.0038364 , 0.00408439,
#        0.00434862, 0.00463221, 0.00493589, 0.00526341, 0.00561091,
#        0.00598589, 0.00638876, 0.0068218 , 0.00728803, 0.00779147,
#        0.00833326, 0.00892767, 0.00955094, 0.0102354 , 0.01097734,
#        0.01178285, 0.01265891]), 'use_nugget': False, 'maxlag': 11, 'n_lags': 22, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [10.5, 10])}}
#
# --- Processing File Key: 123178 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 35.99960246795207, 'normalized_sill': 0.008176735248126392, 'normalized_nugget': 0, 'effective_range': 5.142800352564581, 'sill': 0.08776028974686682, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00391007, 0.00413927, 0.00442987, 0.004744  , 0.00508402,
#        0.00545261, 0.00585278, 0.00628802, 0.00676229, 0.0072802 ,
#        0.00784711, 0.00846929, 0.00915417, 0.00991059]), 'use_nugget': False, 'maxlag': 7, 'n_lags': 14, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [6.5, 10])}}
#
# --- Processing File Key: 123208 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 94.99999999999999, 'normalized_sill': 0.002391939099904677, 'normalized_nugget': 0, 'effective_range': 9.499999999999998, 'sill': 0.04436635255125297, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00329554, 0.00347131, 0.00369537, 0.00393491, 0.0041914 ,
#        0.00446618, 0.00476077, 0.00507679, 0.00541703, 0.00578079,
#        0.00617301, 0.00659491, 0.00704944, 0.00753961, 0.00806882,
#        0.00864087, 0.00926922, 0.0099327 , 0.01066156, 0.01145426]), 'use_nugget': False, 'maxlag': 10, 'n_lags': 20, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [9.5, 10])}}
#
# --- Processing File Key: 124801 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 24.329940314076435, 'normalized_sill': 0.000547602718065879, 'normalized_nugget': 0, 'effective_range': 2.7033267015640483, 'sill': 0.019547763660388875, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00351334, 0.00370719, 0.00395367, 0.00421773, 0.00450258,
#        0.004807  , 0.00513579, 0.00549011, 0.00587498, 0.00628428,
#        0.00672982, 0.00721209, 0.00773459, 0.00830211, 0.00891932,
#        0.00959276, 0.01034301, 0.01113193]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 124802 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 20.03456061969801, 'normalized_sill': 0.0003411631198768657, 'normalized_nugget': 0, 'effective_range': 2.504320077462251, 'sill': 0.01684021009291584, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.003723  , 0.00393519, 0.00420494, 0.00449455, 0.00480827,
#        0.00514468, 0.00550925, 0.00590448, 0.00633637, 0.00679742,
#        0.00730278, 0.00785345, 0.00845444, 0.00911256, 0.00983482,
#        0.01063101]), 'use_nugget': False, 'maxlag': 8, 'n_lags': 16, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [7.5, 10])}}
#
# --- Processing File Key: 125043 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 13.368196931907363, 'normalized_sill': 0.0029121636067998796, 'normalized_nugget': 0, 'effective_range': 2.2280328219845607, 'sill': 0.04876595152401543, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.0042883 , 0.00455621, 0.00489494, 0.00526403, 0.00566707,
#        0.00610821, 0.00659233, 0.00712521, 0.00771539, 0.00836742,
#        0.00909409, 0.00990736]), 'use_nugget': False, 'maxlag': 6, 'n_lags': 12, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [5.5, 10])}}
#
# --- Processing File Key: 126232 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 22.764969477373878, 'normalized_sill': 0.0023369099342331204, 'normalized_nugget': 0, 'effective_range': 2.529441053041542, 'sill': 0.044155972881517194, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00346692, 0.0036566 , 0.00389779, 0.00415652, 0.00443461,
#        0.00473308, 0.00505403, 0.00539946, 0.00577159, 0.00617291,
#        0.00660619, 0.00707455, 0.0075815 , 0.00813102, 0.00872762,
#        0.00937646, 0.01008853, 0.01085613]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 128450 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 16.80001104608095, 'normalized_sill': 0.00023881571841369423, 'normalized_nugget': 0, 'effective_range': 2.1000013807601188, 'sill': 0.014795935588865472, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00366789, 0.00387484, 0.00413758, 0.00442036, 0.00472538,
#        0.00505395, 0.00540869, 0.00579215, 0.00620721, 0.00665711,
#        0.00714557, 0.00767679, 0.00825564, 0.00888773, 0.00958076,
#        0.01034017]), 'use_nugget': False, 'maxlag': 8, 'n_lags': 16, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [7.5, 10])}}
#
# --- Processing File Key: 136515 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 49.6788220048845, 'normalized_sill': 0.0012899631820975739, 'normalized_nugget': 0, 'effective_range': 5.519869111653834, 'sill': 0.03556442275707717, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00349163, 0.00368552, 0.00393008, 0.00419133, 0.00447406,
#        0.00477531, 0.00510083, 0.00545112, 0.00581791, 0.00620812,
#        0.00664521, 0.00711792, 0.00762958, 0.00818497, 0.00878771,
#        0.00944375, 0.01017613, 0.01094303]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 139896 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 34.83552288867818, 'normalized_sill': 0.05126185150986106, 'normalized_nugget': 0, 'effective_range': 3.1668657171525614, 'sill': 0.20484044993506834, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00318225, 0.00334942, 0.00356258, 0.00378994, 0.00403381,
#        0.00429328, 0.00457148, 0.00486971, 0.00519112, 0.00553141,
#        0.00589859, 0.00629279, 0.00671615, 0.00717156, 0.0076623 ,
#        0.00819094, 0.00877011, 0.00937585, 0.01004063, 0.01076018,
#        0.01154016, 0.01238697]), 'use_nugget': False, 'maxlag': 11, 'n_lags': 22, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [10.5, 10])}}
#
# --- Processing File Key: 139897 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 6.755114096846077, 'normalized_sill': 0.020343431405398012, 'normalized_nugget': 0, 'effective_range': 0.9650162995494396, 'sill': 0.13040150926149277, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00401828, 0.00425819, 0.00456257, 0.00489152, 0.00524998,
#        0.005637  , 0.00605969, 0.00652099, 0.0070301 , 0.00757835,
#        0.00818602, 0.0088562 , 0.00959752, 0.01042193]), 'use_nugget': False, 'maxlag': 7, 'n_lags': 14, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [6.5, 10])}}
#
# --- Processing File Key: 140250 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 55.582083748338796, 'normalized_sill': 0.01956316971642927, 'normalized_nugget': 0, 'effective_range': 6.9477604685423495, 'sill': 0.13776242025079966, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00372328, 0.00393549, 0.00420444, 0.00449419, 0.00480767,
#        0.00514491, 0.00550966, 0.00590448, 0.00633554, 0.00679742,
#        0.00730278, 0.00785345, 0.00845444, 0.0091135 , 0.00983588,
#        0.01063101]), 'use_nugget': False, 'maxlag': 8, 'n_lags': 16, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [7.5, 10])}}
#
# --- Processing File Key: 140251 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 39.69500459172377, 'normalized_sill': 0.0036284552527557066, 'normalized_nugget': 0, 'effective_range': 4.410556065747086, 'sill': 0.05637767342917242, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00351358, 0.00370744, 0.00395353, 0.00421773, 0.00450208,
#        0.00480718, 0.00513572, 0.00548966, 0.00587432, 0.00628428,
#        0.00672982, 0.00721209, 0.00773459, 0.00830281, 0.00892011,
#        0.00959276, 0.01034099, 0.01113193]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 140253 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 45.36849389968388, 'normalized_sill': 0.07664304838866018, 'normalized_nugget': 0, 'effective_range': 5.671061737460485, 'sill': 0.24489383502632273, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00378184, 0.00399907, 0.00427535, 0.00457262, 0.00489463,
#        0.00524072, 0.00561651, 0.00602361, 0.00646921, 0.00694662,
#        0.00747043, 0.00804242, 0.00866814, 0.00935517, 0.01011253,
#        0.01094786]), 'use_nugget': False, 'maxlag': 8, 'n_lags': 16, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [7.5, 10])}}
#
# --- Processing File Key: 140254 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 30.306558216088273, 'normalized_sill': 0.014197820421446523, 'normalized_nugget': 0, 'effective_range': 2.755141656008025, 'sill': 0.1009456075660349, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00321877, 0.00338855, 0.00360511, 0.0038364 , 0.00408439,
#        0.00434862, 0.00463221, 0.00493589, 0.00526341, 0.00561091,
#        0.00598589, 0.00638876, 0.0068218 , 0.00728803, 0.00779147,
#        0.00833326, 0.00892767, 0.00955094, 0.0102354 , 0.01097734,
#        0.01178285, 0.01265891]), 'use_nugget': False, 'maxlag': 11, 'n_lags': 22, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [10.5, 10])}}
#
# --- Processing File Key: 140257 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 24.684981823351333, 'normalized_sill': 0.004371976019050066, 'normalized_nugget': 0, 'effective_range': 2.244089256668303, 'sill': 0.05876614167205909, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00321895, 0.00338874, 0.00360511, 0.0038364 , 0.00408402,
#        0.00434875, 0.00463221, 0.00493589, 0.00526306, 0.00561091,
#        0.00598589, 0.00638876, 0.00682223, 0.00728851, 0.00779083,
#        0.00833255, 0.00892637, 0.00955094, 0.0102354 , 0.01097734,
#        0.01178285, 0.01265891]), 'use_nugget': False, 'maxlag': 11, 'n_lags': 22, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [10.5, 10])}}
#
# --- Processing File Key: 140260 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 32.08842495464823, 'normalized_sill': 0.05330083635873966, 'normalized_nugget': 0, 'effective_range': 3.5653805505164704, 'sill': 0.19997524626204297, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00356267, 0.00376046, 0.00401203, 0.00428204, 0.00457325,
#        0.00488506, 0.00522235, 0.00558548, 0.00598039, 0.00640161,
#        0.00686035, 0.00735761, 0.00789721, 0.00848432, 0.00912492,
#        0.00982361, 0.01060424, 0.0114284 ]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 140262 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 14.88338136981549, 'normalized_sill': 0.05382825176498428, 'normalized_nugget': 0, 'effective_range': 2.12619733854507, 'sill': 0.2069852900443952, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00404754, 0.00429016, 0.00459798, 0.00493123, 0.00529438,
#        0.00568681, 0.00611593, 0.00658419, 0.00710153, 0.00765969,
#        0.00827887, 0.0089627 , 0.0097203 , 0.01056437]), 'use_nugget': False, 'maxlag': 7, 'n_lags': 14, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [6.5, 10])}}
#
# --- Processing File Key: 140263 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 94.99999999999999, 'normalized_sill': 0.0020296667679265785, 'normalized_nugget': 0, 'effective_range': 9.499999999999998, 'sill': 0.041282520626564255, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00337766, 0.00356001, 0.00379229, 0.0040409 , 0.00430816,
#        0.00459351, 0.00490065, 0.00523048, 0.00558748, 0.00596709,
#        0.00637885, 0.00682241, 0.00730107, 0.0078187 , 0.00837964,
#        0.00898704, 0.00965848, 0.01036424, 0.01114582, 0.01199929]), 'use_nugget': False, 'maxlag': 10, 'n_lags': 20, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [9.5, 10])}}
#
# --- Processing File Key: 141748 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 14.695905456292301, 'normalized_sill': 0.006604796425194823, 'normalized_nugget': 0, 'effective_range': 1.8369881820365377, 'sill': 0.07062816991116748, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00361362, 0.00381609, 0.00407335, 0.00434938, 0.00464809,
#        0.00496745, 0.0053127 , 0.005686  , 0.00609261, 0.00652576,
#        0.00699877, 0.00751231, 0.00807053, 0.00867908, 0.0093436 ,
#        0.01007197]), 'use_nugget': False, 'maxlag': 8, 'n_lags': 16, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [7.5, 10])}}
#
# --- Processing File Key: 148992 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 27.30799957344286, 'normalized_sill': 0.016593990387390536, 'normalized_nugget': 0, 'effective_range': 2.482545415767533, 'sill': 0.11566129540478777, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00312167, 0.00328607, 0.00349676, 0.00371799, 0.0039557 ,
#        0.00420795, 0.00447834, 0.0047678 , 0.00507973, 0.00540948,
#        0.00576494, 0.0061461 , 0.006555  , 0.00699418, 0.00746622,
#        0.00793935, 0.00845525, 0.00901316, 0.00963845, 0.01031333,
#        0.01104262, 0.01183174]), 'use_nugget': False, 'maxlag': 11, 'n_lags': 22, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [10.5, 10])}}
#
# --- Processing File Key: 148995 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 51.98084016386119, 'normalized_sill': 0.024237186756076303, 'normalized_nugget': 0, 'effective_range': 3.9985261664508607, 'sill': 0.14286134212250584, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00290512, 0.00305206, 0.00323988, 0.00343928, 0.00365279,
#        0.00387889, 0.00412045, 0.00437809, 0.00465489, 0.00494657,
#        0.0052597 , 0.00559414, 0.00595138, 0.0063334 , 0.006742  ,
#        0.00717928, 0.0076547 , 0.00814988, 0.00868779, 0.0092649 ,
#        0.00988452, 0.01055029, 0.01126712, 0.01203787, 0.01286794,
#        0.01376355]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 148998 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 27.594497790487456, 'normalized_sill': 0.020548771405532115, 'normalized_nugget': 0, 'effective_range': 2.5085907082261323, 'sill': 0.12472139410228891, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00308333, 0.0032432 , 0.00344715, 0.00366406, 0.00389697,
#        0.00414401, 0.00440864, 0.00469162, 0.00499673, 0.00531865,
#        0.00566553, 0.00603718, 0.00643549, 0.00686297, 0.00732193,
#        0.00781508, 0.0083554 , 0.00891787, 0.00953306, 0.01019658,
#        0.01091303, 0.01168759]), 'use_nugget': False, 'maxlag': 11, 'n_lags': 22, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [10.5, 10])}}
#
# --- Processing File Key: 148999 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 115.49999999999999, 'normalized_sill': 0.014023095511860885, 'normalized_nugget': 0, 'effective_range': 10.499999999999998, 'sill': 0.10983001246921777, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00308333, 0.0032432 , 0.00344715, 0.00366406, 0.00389697,
#        0.00414401, 0.00440864, 0.00469162, 0.00499673, 0.00531865,
#        0.00566553, 0.00603718, 0.00643549, 0.00686297, 0.00732193,
#        0.00781508, 0.0083554 , 0.00891787, 0.00953306, 0.01019658,
#        0.01091303, 0.01168759]), 'use_nugget': False, 'maxlag': 11, 'n_lags': 22, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [10.5, 10])}}
#
# ...
#        0.00383558, 0.00407349, 0.00432733, 0.00459931, 0.00488646,
#        0.00519434, 0.00552302, 0.00587393, 0.00624898, 0.0066499 ,
#        0.00707906, 0.00754407, 0.00802956, 0.008556  , 0.00912036,
#        0.00972581, 0.0103758 , 0.01107416, 0.0118251 , 0.01263399,
#        0.01350476]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 192469 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 56.53785005384993, 'normalized_sill': 0.0033738400891319387, 'normalized_nugget': 0, 'effective_range': 4.038417860989281, 'sill': 0.05555621547129065, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00279994, 0.00293932, 0.00311784, 0.00330761, 0.0035099 ,
#        0.00372447, 0.00395333, 0.00419693, 0.00445761, 0.00473304,
#        0.00502777, 0.00534203, 0.00567715, 0.00603486, 0.00641701,
#        0.00682485, 0.00726574, 0.0077267 , 0.00822495, 0.00875813,
#        0.00932902, 0.00994065, 0.01059635, 0.01129978, 0.01205467,
#        0.01286602, 0.01373846, 0.01467744]), 'use_nugget': False, 'maxlag': 14, 'n_lags': 28, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [13.5, 10])}}
#
# --- Processing File Key: 192473 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 40.488190226552966, 'normalized_sill': 0.0021385743515213297, 'normalized_nugget': 0, 'effective_range': 3.374015852212747, 'sill': 0.03423641660653606, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00301756, 0.00317226, 0.00336996, 0.00358059, 0.00380578,
#        0.00404514, 0.00430121, 0.00457458, 0.00486821, 0.00517905,
#        0.00551301, 0.00587039, 0.0062529 , 0.00666283, 0.00710271,
#        0.00757421, 0.00808744, 0.00862456, 0.0092094 , 0.00983884,
#        0.01051781, 0.01124919, 0.01203884, 0.01289242]), 'use_nugget': False, 'maxlag': 12, 'n_lags': 24, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [11.5, 10])}}
#
# --- Processing File Key: 192478 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 30.270646619225747, 'normalized_sill': 0.011580964072512068, 'normalized_nugget': 0, 'effective_range': 3.7838308274032184, 'sill': 0.093972005947885, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00378184, 0.00399907, 0.00427535, 0.00457262, 0.00489463,
#        0.00524072, 0.00561651, 0.00602361, 0.00646921, 0.00694662,
#        0.00747043, 0.00804242, 0.00866814, 0.00935517, 0.01011253,
#        0.01094786]), 'use_nugget': False, 'maxlag': 8, 'n_lags': 16, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [7.5, 10])}}
#
# --- Processing File Key: 192480 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 54.81773715907658, 'normalized_sill': 0.001407285381560384, 'normalized_nugget': 0, 'effective_range': 4.21674901223666, 'sill': 0.032028368136011114, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00287578, 0.00302053, 0.00320569, 0.0034025 , 0.00361268,
#        0.00383558, 0.00407349, 0.00432733, 0.00459931, 0.00488646,
#        0.00519434, 0.00552302, 0.00587393, 0.00624898, 0.0066499 ,
#        0.00707906, 0.00754407, 0.00802956, 0.008556  , 0.00912036,
#        0.00972581, 0.0103758 , 0.01107416, 0.0118251 , 0.01263399,
#        0.01350476]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 192483 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 69.62949507059176, 'normalized_sill': 0.001385862878233237, 'normalized_nugget': 0, 'effective_range': 5.356115005430135, 'sill': 0.03344487864906426, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00287578, 0.00302053, 0.00320569, 0.0034025 , 0.00361268,
#        0.00383558, 0.00407349, 0.00432733, 0.00459931, 0.00488646,
#        0.00519434, 0.00552302, 0.00587393, 0.00624898, 0.0066499 ,
#        0.00707906, 0.00754407, 0.00802956, 0.008556  , 0.00912036,
#        0.00972581, 0.0103758 , 0.01107416, 0.0118251 , 0.01263399,
#        0.01350476]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 195188 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 44.57441782066523, 'normalized_sill': 0.020122286332363723, 'normalized_nugget': 0, 'effective_range': 4.952713091185026, 'sill': 0.1295844141344141, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00351334, 0.00370719, 0.00395367, 0.00421773, 0.00450258,
#        0.004807  , 0.00513579, 0.00549011, 0.00587498, 0.00628428,
#        0.00672982, 0.00721209, 0.00773459, 0.00830211, 0.00891932,
#        0.00959276, 0.01034301, 0.01113193]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 195941 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 76.49999999999999, 'normalized_sill': 0.016357242570701723, 'normalized_nugget': 0, 'effective_range': 8.499999999999998, 'sill': 0.11979276081004582, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00346647, 0.00365612, 0.00389752, 0.00415623, 0.00443477,
#        0.00473256, 0.00505365, 0.00539903, 0.00577417, 0.00617317,
#        0.00660648, 0.00707487, 0.00758162, 0.00813115, 0.00872851,
#        0.00937745, 0.0100983 , 0.0108574 ]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 196093 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 162.49999999999997, 'normalized_sill': 0.0010295703364437067, 'normalized_nugget': 0, 'effective_range': 12.499999999999998, 'sill': 0.021806876120599172, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.0029307 , 0.00307931, 0.00326907, 0.0034712 , 0.00368685,
#        0.00391635, 0.00416117, 0.0044223 , 0.00470223, 0.00499858,
#        0.0053163 , 0.00565578, 0.00601857, 0.00640702, 0.0068224 ,
#        0.00726715, 0.00774943, 0.00825477, 0.00880283, 0.00939121,
#        0.01002339, 0.01070319, 0.01143485, 0.01222309, 0.01307391,
#        0.01399181]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 205817 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 27.660638663731497, 'normalized_sill': 0.0013239146001406796, 'normalized_nugget': 0, 'effective_range': 2.1277414356716537, 'sill': 0.02904856231385536, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00293112, 0.00307976, 0.00326979, 0.0034719 , 0.0036879 ,
#        0.00391708, 0.00416188, 0.00442328, 0.00470363, 0.00499973,
#        0.00531683, 0.00565578, 0.00601857, 0.0064067 , 0.00682204,
#        0.00726715, 0.00775023, 0.00825477, 0.00880283, 0.00939121,
#        0.01002339, 0.01070319, 0.01143575, 0.01222409, 0.01307391,
#        0.01399181]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 205818 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 20.182398823588848, 'normalized_sill': 0.00280318319913962, 'normalized_nugget': 0, 'effective_range': 1.4415999159706319, 'sill': 0.04783174824216423, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00275369, 0.00289018, 0.00306493, 0.00325018, 0.00344796,
#        0.00365689, 0.00388009, 0.00411767, 0.00437227, 0.00464027,
#        0.00492722, 0.00523297, 0.00555879, 0.0059063 , 0.00627698,
#        0.00667248, 0.00710064, 0.00754639, 0.00802833, 0.00854354,
#        0.00909458, 0.00968426, 0.01031566, 0.01099214, 0.01171711,
#        0.01249514, 0.01333043, 0.0142279 ]), 'use_nugget': False, 'maxlag': 14, 'n_lags': 28, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [13.5, 10])}}
#
# --- Processing File Key: 217000 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 17.98110105655403, 'normalized_sill': 0.00010561430019152433, 'normalized_nugget': 0, 'effective_range': 1.9979001173948923, 'sill': 0.010000000000000002, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00338155, 0.00356468, 0.00379763, 0.00404624, 0.0043146 ,
#        0.00460017, 0.00490768, 0.00523821, 0.00559751, 0.00597736,
#        0.00638968, 0.00683439, 0.00731437, 0.00783348, 0.00839544,
#        0.00900468, 0.00968078, 0.01038732]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 218529 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 57.31134705468757, 'normalized_sill': 0.00036137948372991734, 'normalized_nugget': 0, 'effective_range': 6.367927450520842, 'sill': 0.016332332511038713, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00351334, 0.00370719, 0.00395367, 0.00421773, 0.00450258,
#        0.004807  , 0.00513579, 0.00549011, 0.00587498, 0.00628428,
#        0.00672982, 0.00721209, 0.00773459, 0.00830211, 0.00891932,
#        0.00959276, 0.01034301, 0.01113193]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 218970 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 188.22441647275005, 'normalized_sill': 0.003907551784324596, 'normalized_nugget': 0, 'effective_range': 13.444601176625003, 'sill': 0.05743979915071465, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.0027758 , 0.00291367, 0.00309021, 0.0032777 , 0.00347765,
#        0.00368953, 0.00391537, 0.00415602, 0.00441344, 0.00468502,
#        0.0049757 , 0.00528555, 0.00561583, 0.00596823, 0.00634427,
#        0.00674602, 0.00718004, 0.00763311, 0.00812285, 0.00864665,
#        0.00920717, 0.00980733, 0.01045032, 0.01113964, 0.01187886,
#        0.01267273, 0.01352567, 0.01444284]), 'use_nugget': False, 'maxlag': 14, 'n_lags': 28, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [13.5, 10])}}
#
# --- Processing File Key: 229870 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 30.70223655497606, 'normalized_sill': 0.008061205747527429, 'normalized_nugget': 0, 'effective_range': 2.1930168967840045, 'sill': 0.07942174954404493, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00282453, 0.00296565, 0.00314633, 0.00333835, 0.00354319,
#        0.00376043, 0.00399217, 0.00423908, 0.00450341, 0.00478256,
#        0.0050815 , 0.00540037, 0.00574053, 0.00610377, 0.00649185,
#        0.00690652, 0.00735513, 0.00782381, 0.00833099, 0.00887404,
#        0.00945584, 0.01007956, 0.01074868, 0.01146703, 0.01223853,
#        0.01306843, 0.01396216, 0.01492507]), 'use_nugget': False, 'maxlag': 14, 'n_lags': 28, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [13.5, 10])}}
#
# --- Processing File Key: 234267 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 48.08212859547031, 'normalized_sill': 0.028399125468281935, 'normalized_nugget': 0, 'effective_range': 4.808212859547031, 'sill': 0.16075588305895397, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00337766, 0.00356001, 0.00379229, 0.0040409 , 0.00430816,
#        0.00459351, 0.00490065, 0.00523048, 0.00558748, 0.00596709,
#        0.00637885, 0.00682241, 0.00730107, 0.0078187 , 0.00837964,
#        0.00898704, 0.00965848, 0.01036424, 0.01114582, 0.01199929]), 'use_nugget': False, 'maxlag': 10, 'n_lags': 20, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [9.5, 10])}}
#
# --- Processing File Key: 240353 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 94.99999999999999, 'normalized_sill': 0.01139490442534717, 'normalized_nugget': 0, 'effective_range': 9.499999999999998, 'sill': 0.08295404820257851, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00325686, 0.00342996, 0.00365036, 0.00388554, 0.00413829,
#        0.00440733, 0.0046962 , 0.00500615, 0.0053411 , 0.00569565,
#        0.00607905, 0.00649156, 0.00693541, 0.00741348, 0.00792906,
#        0.00848609, 0.00909914, 0.00974003, 0.01044622, 0.01121296]), 'use_nugget': False, 'maxlag': 10, 'n_lags': 20, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [9.5, 10])}}
#
# --- Variogram analysis complete ---
# Results saved to the 'variogram_model_fit_WLS_exponential_exp_0.5' folder with WLS option 'exp'.

# %%
# -----------------------------------------------------------------------------
# Part 2: Load summary and plot fitted variogram curves from parameters
# -----------------------------------------------------------------------------

def exponential_variogram_func(h, nugget, sill, effective_range):
    """
    y = nugget + (sill - nugget) * (1 - exp(-h/a)), where a is the range parameter.
    This function now assumes normalized nugget and sill values.
    """
    partial_sill = sill - nugget

    # The range parameter 'a' is effective_range / 3 for the exponential model
    a = effective_range / 3

    if isinstance(h, (np.ndarray, list)):
        h = np.array(h)
        if np.isclose(a, 0):
            fitted_curve = np.full_like(h, sill)
        else:
            fitted_curve = nugget + partial_sill * (1 - np.exp(-h / a))

        fitted_curve[h == 0] = nugget

        return fitted_curve
    else:
        if np.isclose(h, 0):
            return nugget
        if np.isclose(a, 0):
            return sill
        return nugget + partial_sill * (1 - np.exp(-h / a))

# Use the correct summary file path from our previous conversation,
# which includes the 'Check' column.
SUMMARY_PATH = 'variogram_model_fit_WLS_exponential_exp_0.5/variogram_parameters_summary_WLS_exp.csv'

if not os.path.exists(SUMMARY_PATH):
    print(f"Error: The summary file '{SUMMARY_PATH}' was not found.")
else:
    summary = pd.read_csv(SUMMARY_PATH)

    if 'maxlag' not in summary.columns:
        print("Error: 'maxlag' column not found in the summary file. Please run the previous script to include it.")
        exit()

    # Check for 'sill_normalized' and 'nugget_normalized' columns
    if 'sill_normalized' not in summary.columns:
        print("Warning: 'sill_normalized' column not found. Calculating it now.")

        # This requires the original data to get the variance for normalization
        # We'll assume the variance is a good approximation of the sill if not normalized.
        # It's better to add the calculation to the first part of the script.
        # For now, we'll try to approximate it.
        # A more robust solution is to re-run the first script after adding 'var_val' to the summary.

        # As a temporary workaround, we'll just use the raw sill and nugget, and the plot won't be normalized.
        # We will add a note to the user.
        print("The plot will not be normalized as required data is missing. Please ensure the 'sill_normalized' and 'nugget_normalized' columns are in the summary file.")

        # Filter for valid models using the 'Check' column.
        valid_models = summary[summary['Check'].isna()]

        # Calculate counts
        removed = len(summary) - len(valid_models)
        kept = len(valid_models)
        total = len(summary)

        plt.figure(figsize=(8, 5))

        if not valid_models.empty:
            max_x_plot = max(valid_models['effective_range'].max() * 1.2, valid_models['maxlag'].max())
            if pd.isna(max_x_plot):
                max_x_plot = 50

            for index, row in valid_models.iterrows():
                nugget = row['nugget']
                sill = row['sill_normalized']
                effective_range = row['effective_range']
                maxlag_for_curve = row['maxlag']
                lag_dense_individual = np.arange(0, maxlag_for_curve + 0.1, 0.02)
                fitted_curve = [exponential_variogram_func(h, nugget, sill, effective_range) for h in lag_dense_individual]
                plt.plot(lag_dense_individual, fitted_curve, linewidth=3, alpha=0.8)

    else:
        # This is the correct path for a normalized plot
        valid_models = summary[summary['Check'].isna()]
        removed = len(summary) - len(valid_models)
        kept = len(valid_models)
        total = len(summary)

        plt.figure(figsize=(8, 5))

        if not valid_models.empty:
            max_x_plot = max(valid_models['effective_range'].max() * 1.2, valid_models['maxlag'].max())
            if pd.isna(max_x_plot):
                max_x_plot = 50

            for index, row in valid_models.iterrows():
                nugget = row['nugget_normalized'] if 'nugget_normalized' in row else 0 # Use 0 if not available
                sill = row['sill_normalized']
                effective_range = row['effective_range']
                maxlag_for_curve = row['maxlag']
                lag_dense_individual = np.arange(0, maxlag_for_curve + 0.1, 0.02)
                fitted_curve = [exponential_variogram_func(h, nugget, sill, effective_range) for h in lag_dense_individual]
                plt.plot(lag_dense_individual, fitted_curve, linewidth=3, alpha=0.8)

        plt.ylim(0, 1.2) # Set y-axis to be 0-1.2 for normalized view

    print(f"\n--- Part 2 Finished ---")
    print(f"Total results: {total}")
    print(f"Number of results removed: {removed}")
    print(f"Number of results plotted: {kept}")

    plt.xlabel('Lag (m)')
    plt.ylabel('Fitted_Semivariance (normalized)')
    plt.title('Fitted Exponential Variogram Curves: All (filtered)')
    plt.grid(True)
    plt.show()
# Out:
# --- Part 2 Finished ---
# Total results: 95
# Number of results removed: 0
# Number of results plotted: 95

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from skgstat import Variogram
from scipy.optimize import curve_fit

# -----------------------------------------------------------------------------
# Exponential variogram functions
# -----------------------------------------------------------------------------
def exponential_variogram_func(h, nugget, sill, effective_range):
    """
    Exponential variogram model with nugget parameter.
    y = nugget + (sill - nugget) * (1 - exp(-h / (effective_range/3)))
    """
    partial_sill = sill - nugget
    a = effective_range / 3

    h = np.array(h)
    if np.isclose(a, 0):
        fitted_curve = np.full_like(h, sill)
    else:
        fitted_curve = nugget + partial_sill * (1 - np.exp(-h / a))
    fitted_curve[h == 0] = nugget
    return fitted_curve

def exponential_variogram_func_fixed_nugget(h, sill, effective_range):
    """
    Exponential variogram with nugget fixed at 0.
    y = 0 + sill * (1 - exp(-h / (effective_range/3)))
    """
    a = effective_range / 3
    h = np.array(h)
    fitted_curve = sill * (1 - np.exp(-h / a))
    fitted_curve[h == 0] = 0.0
    return fitted_curve

# -----------------------------------------------------------------------------
# Part 2: Load summary and generate individual fitted curves
# -----------------------------------------------------------------------------
SUMMARY_PATH = 'variogram_model_fit_simple_exponential_exp/variogram_parameters_summary_WLS_exp.csv'

if not os.path.exists(SUMMARY_PATH):
    print(f"Error: The summary file '{SUMMARY_PATH}' was not found.")
    exit()

summary = pd.read_csv(SUMMARY_PATH)
if 'maxlag' not in summary.columns:
    print("Error: 'maxlag' column not found in the summary file.")
    exit()

# Filter valid models (optional)
valid_summary = summary
removed = len(summary) - len(valid_summary)
kept = len(valid_summary)
total = len(summary)

nuggets = valid_summary['nugget'].values
sills = valid_summary['sill_normalized'].values
ranges = valid_summary['effective_range'].values
maxlags = valid_summary['maxlag'].values

if len(sills) == 0:
    print("No valid variogram models found to plot.")
    exit()

# --- Generate points from individual fitted curves ---
all_generated_lags = []
all_generated_semivariances = []

plt.figure(figsize=(8, 5))

for n, s, r, ml in zip(nuggets, sills, ranges, maxlags):
    lag_grid_individual = np.arange(0, ml + 0.1, 0.1)
    fitted_curve = exponential_variogram_func(lag_grid_individual, n, s, r)
    plt.plot(lag_grid_individual, fitted_curve, color='grey', alpha=0.2)
    all_generated_lags.extend(lag_grid_individual)
    all_generated_semivariances.extend(fitted_curve)

all_generated_lags = np.array(all_generated_lags)
all_generated_semivariances = np.array(all_generated_semivariances)

# -----------------------------------------------------------------------------
# Part 3: Unified curve fit with nugget fixed at 0
# -----------------------------------------------------------------------------
initial_guess = [np.mean(sills), np.mean(ranges)]
bounds_lower = [0.0, 0.0]
bounds_upper = [np.inf, np.inf]

try:
    popt_unified, pcov_unified = curve_fit(
        exponential_variogram_func_fixed_nugget,
        all_generated_lags,
        all_generated_semivariances,
        p0=initial_guess,
        bounds=(bounds_lower, bounds_upper)
    )
    unified_sill, unified_range = popt_unified
    perr_unified = np.sqrt(np.diag(pcov_unified))
    unified_sill_err, unified_range_err = perr_unified

except RuntimeError as e:
    print(f"Error: Unified curve fit failed. {e}")
    exit()

# Plot unified curve
max_lag_unified = np.max(maxlags)
lag_grid_dense = np.arange(0, max_lag_unified + 0.1, 0.1)
unified_curve = exponential_variogram_func_fixed_nugget(lag_grid_dense, unified_sill, unified_range)
plt.plot(lag_grid_dense, unified_curve, color='red', linewidth=3, label='Unified Exponential Model Fit (Nugget=0)')

# ±1 std dev shading
lower_bound_curve = exponential_variogram_func_fixed_nugget(
    lag_grid_dense,
    unified_sill - unified_sill_err,
    unified_range - unified_range_err
)
upper_bound_curve = exponential_variogram_func_fixed_nugget(
    lag_grid_dense,
    unified_sill + unified_sill_err,
    unified_range + unified_range_err
)
plt.fill_between(lag_grid_dense, lower_bound_curve, upper_bound_curve, color='red', alpha=0.3)

# Final plot adjustments
plt.xlabel('Lag (m)')
plt.ylabel('Semivariance')
plt.title('Individual Variogram Fits and Unified Exponential Model (Nugget=0)')
plt.grid(True)
plt.style.use('default')
plt.legend()
plt.ylim(0,1.2)
plt.tight_layout()
plt.savefig('unified_exponential_model_fit_nugget0.png')
plt.show()

# Print results
print("\n--- Part 2 Finished ---")
print(f"Total results: {total}")
print(f"Number of results removed: {removed}")
print(f"Number of results plotted: {kept}")
print("\nUnified Exponential Model Parameters (Nugget fixed at 0):")
print(f"  Nugget: 0.0000 (fixed)")
print(f"  Sill  : {unified_sill:.4f} ± {unified_sill_err:.4f}")
print(f"  Range : {unified_range:.4f} ± {unified_range_err:.4f}")
# Out:
# --- Part 2 Finished ---
# Total results: 90
# Number of results removed: 0
# Number of results plotted: 90
#
# Unified Exponential Model Parameters (Nugget fixed at 0):
#   Nugget: 0.0000 (fixed)
#   Sill  : 0.7599 ± 0.0019
#   Range : 4.3636 ± 0.0513
