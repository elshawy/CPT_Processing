# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from skgstat import Variogram
from scipy.interpolate import interp1d
plt.style.use('default')

# --- 1. Settings and initialization ---
DATA_FILE = 'updated_combined_results.csv'
MODEL_NAME = 'exponential'
OUTPUT_BASE_FOLDER = f'variogram_model_fit_simple_{MODEL_NAME}'
INITIAL_BIN_INTERVAL = 0.5
RETRY_ATTEMPTS = 3
BIN_INTERVAL_MULTIPLIER = 2

os.makedirs(OUTPUT_BASE_FOLDER, exist_ok=True)
overall_summary = []

# Load data
try:
    data = pd.read_csv(DATA_FILE)
except FileNotFoundError:
    print(f"Error: Data file '{DATA_FILE}' not found. Please ensure the file exists.")
    exit()

# --- 2. Variogram analysis loop ---
for key, group_df in data.groupby('File Key_1'):
    print(f"\n--- Processing File Key: {key} ---")

    depth_values = group_df['Depth'].values
    values = group_df['withinres'].values

    if len(depth_values) < 10:
        print(f"  Skipping {key}: Not enough data points ({len(depth_values)} < 10).")
        continue

    coordinates = np.vstack([depth_values]).T
    maxlag = max(1, int((np.max(depth_values) - np.min(depth_values)) / 2))
    current_bin_interval = INITIAL_BIN_INTERVAL

    for attempt in range(RETRY_ATTEMPTS):
        try:
            n_lags = max(2, int(maxlag / current_bin_interval))
            V = Variogram(
                coordinates,
                values,
                model=MODEL_NAME,
                maxlag=maxlag,
                n_lags=n_lags,
                normalize=True,  # 순수 계산
                use_nugget=False,
                fit_method='trf',
                fit_sill=True,
                fit_range=True
            )

            # --- Extract data ---
            bins = V.bins
            semivars = V.experimental
            y_fit = V.fitted_model(bins)
            counts = V.bin_count

            # --- Visualize and save ---
            fig = V.plot(show=False)
            fig.suptitle(f'Variogram - {key} ({MODEL_NAME}, bin={current_bin_interval:.2f}m)')
            fig.savefig(os.path.join(OUTPUT_BASE_FOLDER, f'{key}_variogram_bin{current_bin_interval:.2f}m.png'))
            plt.close(fig)

            # Save experimental + fitted
            pd.DataFrame({
                'Lag (m)': bins,
                'Semivariance': semivars,
                'Count': counts,
                'Fitted_Semivariance': y_fit
            }).to_csv(os.path.join(OUTPUT_BASE_FOLDER, f'{key}_variogram_bin{current_bin_interval:.2f}m.csv'), index=False)

            # Interpolated fitted curve
            interp_func = interp1d(bins, y_fit, kind='linear', fill_value='extrapolate')
            lag_dense = np.arange(0, maxlag + 0.1, 0.02)
            fitted_dense = interp_func(lag_dense)
            fitted_dense = np.maximum(fitted_dense, 0)
            fitted_dense[lag_dense == 0] = 0

            pd.DataFrame({
                'Lag (m)': lag_dense,
                'Fitted_Semivariance': fitted_dense
            }).to_csv(os.path.join(OUTPUT_BASE_FOLDER, f'{key}_variogram_fitted_curve_bin{current_bin_interval:.2f}m.csv'), index=False)

            # --- Summarize parameters ---
            desc = V.describe()
            effective_range = desc.get('effective_range', np.nan)
            check_note = np.nan
            if not np.isnan(effective_range) and np.isclose(effective_range, maxlag):
                check_note = 'effective_range_eq_maxlag'

            overall_summary.append({
                'File Key_1': key,
                'nugget': desc.get('nugget', np.nan),
                'sill': desc.get('sill', np.nan),
                'effective_range': effective_range,
                'smoothness': desc.get('smoothness', np.nan),
                'maxlag': maxlag,
                'bin_interval_used': current_bin_interval,
                'Check': check_note
            })

            break  # 성공 시 반복 종료

        except Exception as e:
            print(f"  Failed attempt {attempt+1} for {key} with bin_interval {current_bin_interval:.2f}m: {e}")
            current_bin_interval *= BIN_INTERVAL_MULTIPLIER
            if attempt == RETRY_ATTEMPTS - 1:
                overall_summary.append({
                    'File Key_1': key,
                    'nugget': np.nan,
                    'sill': np.nan,
                    'effective_range': np.nan,
                    'smoothness': np.nan,
                    'maxlag': maxlag,
                    'bin_interval_used': current_bin_interval / BIN_INTERVAL_MULTIPLIER,
                    'Check': 'Failed'
                })

# --- Save final summary ---
pd.DataFrame(overall_summary).to_csv(
    os.path.join(OUTPUT_BASE_FOLDER, 'variogram_parameters_summary.csv'),
    index=False
)

print("\n--- Variogram analysis complete ---")
print(f"Results saved to the '{OUTPUT_BASE_FOLDER}' folder.")
# Out:
# --- Processing File Key: 66983 ---
#
# --- Processing File Key: 66984 ---
#
# --- Processing File Key: 92524 ---
#
# --- Processing File Key: 92525 ---
#
# --- Processing File Key: 92526 ---
#
# --- Processing File Key: 92527 ---
#
# --- Processing File Key: 92534 ---
#
# --- Processing File Key: 92535 ---
#
# --- Processing File Key: 92536 ---
#
# --- Processing File Key: 92537 ---
#
# --- Processing File Key: 92538 ---
#
# --- Processing File Key: 92539 ---
#
# --- Processing File Key: 92540 ---
#
# --- Processing File Key: 92541 ---
#
# --- Processing File Key: 92542 ---
#
# --- Processing File Key: 92543 ---
#
# --- Processing File Key: 92544 ---
#
# --- Processing File Key: 92545 ---
#
# --- Processing File Key: 92546 ---
#
# --- Processing File Key: 92547 ---
#
# --- Processing File Key: 92548 ---
#
# --- Processing File Key: 92549 ---
#
# --- Processing File Key: 92554 ---
#
# --- Processing File Key: 92555 ---
#
# --- Processing File Key: 92556 ---
#
# --- Processing File Key: 92557 ---
#
# --- Processing File Key: 94658 ---
#
# --- Processing File Key: 100703 ---
#
# --- Processing File Key: 114319 ---
#
# --- Processing File Key: 114322 ---
#
# --- Processing File Key: 122141 ---
#
# --- Processing File Key: 123178 ---
#
# --- Processing File Key: 123208 ---
#
# --- Processing File Key: 124801 ---
#
# --- Processing File Key: 124802 ---
#
# --- Processing File Key: 125043 ---
#
# --- Processing File Key: 126232 ---
#
# --- Processing File Key: 128450 ---
#
# --- Processing File Key: 136515 ---
#
# --- Processing File Key: 139896 ---
#
# --- Processing File Key: 139897 ---
#
# --- Processing File Key: 140250 ---
#
# --- Processing File Key: 140251 ---
#
# --- Processing File Key: 140253 ---
#
# --- Processing File Key: 140254 ---
#
# --- Processing File Key: 140257 ---
#
# --- Processing File Key: 140260 ---
#
# --- Processing File Key: 140262 ---
#
# --- Processing File Key: 140263 ---
#
# --- Processing File Key: 141748 ---
#
# --- Processing File Key: 148992 ---
#
# --- Processing File Key: 148995 ---
#
# --- Processing File Key: 148998 ---
#
# --- Processing File Key: 148999 ---
#
# --- Processing File Key: 154032 ---
#
# --- Processing File Key: 154771 ---
#
# --- Processing File Key: 154775 ---
#
# --- Processing File Key: 156296 ---
#
# --- Processing File Key: 156298 ---
#
# --- Processing File Key: 156300 ---
#
# --- Processing File Key: 156301 ---
#
# --- Processing File Key: 156307 ---
#
# --- Processing File Key: 156308 ---
#
# --- Processing File Key: 156310 ---
#
# --- Processing File Key: 156311 ---
#
# --- Processing File Key: 156435 ---
#
# --- Processing File Key: 156436 ---
#
# --- Processing File Key: 156437 ---
#
# --- Processing File Key: 156438 ---
#
# --- Processing File Key: 165738 ---
#
# --- Processing File Key: 165739 ---
#
# --- Processing File Key: 167294 ---
#
# --- Processing File Key: 173187 ---
#
# --- Processing File Key: 178944 ---
#
# --- Processing File Key: 178947 ---
#
# --- Processing File Key: 183366 ---
#
# --- Processing File Key: 184148 ---
#
# --- Processing File Key: 192457 ---
#
# --- Processing File Key: 192465 ---
#
# --- Processing File Key: 192469 ---
#
# --- Processing File Key: 192473 ---
#
# --- Processing File Key: 192478 ---
#
# --- Processing File Key: 192480 ---
#
# --- Processing File Key: 192483 ---
#
# --- Processing File Key: 195188 ---
#
# --- Processing File Key: 195941 ---
#
# --- Processing File Key: 196093 ---
#
# --- Processing File Key: 205817 ---
#
# --- Processing File Key: 205818 ---
#
# --- Processing File Key: 217000 ---
#
# --- Variogram analysis complete ---
# Results saved to the 'variogram_model_fit_simple_exponential' folder.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from skgstat import Variogram
from scipy.interpolate import interp1d

# --- WLS weighting option ---
# 'default': sigma = sqrt(h^2 / n)
# 'exp': sigma = 1 / sqrt(n * exp(-lag / c))
WLS_OPTION = 'exp'   # 선택: 'default' 또는 'exp'
C_DECAY = 5          # exp 가중치에서 c 값 (상관거리 감쇠 계수)

# --- 1. Settings and initialization ---
DATA_FILE = 'updated_combined_results.csv'
MODEL_NAME = 'exponential'
OUTPUT_BASE_FOLDER = f'variogram_model_fit_simple_{MODEL_NAME}_{WLS_OPTION}'
INITIAL_BIN_INTERVAL = 0.5
RETRY_ATTEMPTS = 3
BIN_INTERVAL_MULTIPLIER = 2

os.makedirs(OUTPUT_BASE_FOLDER, exist_ok=True)
overall_summary = []

# Load data
try:
    data = pd.read_csv(DATA_FILE)
except FileNotFoundError:
    print(f"Error: Data file '{DATA_FILE}' not found. Please ensure the file exists.")
    exit()

# --- 2. Variogram analysis loop ---
for key, group_df in data.groupby('File Key_1'):
    print(f"\n--- Processing File Key: {key} ---")

    depth_values = group_df['Depth'].values
    values = group_df['withinres'].values

    if len(depth_values) < 10:
        print(f"  Skipping {key}: Not enough data points ({len(depth_values)} < 10).")
        continue

    coordinates = np.vstack([depth_values]).T
    maxlag = max(1, int((np.max(depth_values) - np.min(depth_values)) / 2))
    current_bin_interval = INITIAL_BIN_INTERVAL

    for attempt in range(RETRY_ATTEMPTS):
        try:
            n_lags = max(2, int(maxlag / current_bin_interval))

            # --- 1. Preliminary variogram to get bin counts ---
            V_tmp = Variogram(
                coordinates,
                values,
                model=MODEL_NAME,
                maxlag=maxlag,
                n_lags=n_lags,
                normalize=True,
                fit_method=None
            )

            bins = V_tmp.bins
            counts = V_tmp.bin_count

            # --- 2. WLS sigma calculation ---
            counts_safe = np.where(counts == 0, np.nan, counts)
            bins_safe = np.where(bins == 0, np.nan, bins)

            if WLS_OPTION == 'default':
                sigma_vals = np.sqrt(bins_safe**2 / counts_safe)
            elif WLS_OPTION == 'exp':
                weights = counts_safe * np.exp(-bins_safe / C_DECAY)
                sigma_vals = 1 / np.sqrt(weights)
            else:
                raise ValueError(f"Unknown WLS_OPTION: {WLS_OPTION}")

            max_sigma = np.nanmax(sigma_vals[~np.isnan(sigma_vals)]) if np.any(~np.isnan(sigma_vals)) else 1.0
            sigma_vals = np.nan_to_num(sigma_vals, nan=max_sigma)
            min_range_bound = current_bin_interval
            max_range_bound = maxlag - current_bin_interval
            sill_min = 0.01
            sill_max = 10
            fit_bounds = ([min_range_bound, sill_min], [max_range_bound, sill_max])

            # --- 3. Final WLS variogram fitting ---
            V = Variogram(
                coordinates,
                values,
                model=MODEL_NAME,
                maxlag=maxlag,
                n_lags=n_lags,
                normalize=True,
                use_nugget=False,
                fit_method='trf',
                fit_sill=True,
                fit_range=True,
                fit_bounds=fit_bounds,
                fit_sigma=sigma_vals
            )

            # --- Extract data ---
            semivars = V.experimental
            y_fit = V.fitted_model(bins)
            counts = V.bin_count

            # --- Visualize and save ---
            fig = V.plot(show=True)
            fig.suptitle(f'Variogram - {key} ({MODEL_NAME} WLS-{WLS_OPTION}, bin={current_bin_interval:.2f}m)')
            fig.savefig(os.path.join(OUTPUT_BASE_FOLDER, f'{key}_variogram_WLS_{WLS_OPTION}_bin{current_bin_interval:.2f}m.png'))
            plt.close(fig)

            pd.DataFrame({
                'Lag (m)': bins,
                'Semivariance': semivars,
                'Count': counts,
                'Fitted_Semivariance': y_fit
            }).to_csv(os.path.join(OUTPUT_BASE_FOLDER, f'{key}_variogram_WLS_{WLS_OPTION}_bin{current_bin_interval:.2f}m.csv'), index=False)

            # Interpolated fitted curve
            interp_func = interp1d(bins, y_fit, kind='linear', fill_value='extrapolate')
            lag_dense = np.arange(0, maxlag + 0.1, 0.02)
            fitted_dense = interp_func(lag_dense)
            fitted_dense = np.maximum(fitted_dense, 0)
            fitted_dense[lag_dense == 0] = 0

            pd.DataFrame({
                'Lag (m)': lag_dense,
                'Fitted_Semivariance': fitted_dense
            }).to_csv(os.path.join(OUTPUT_BASE_FOLDER, f'{key}_variogram_fitted_curve_WLS_{WLS_OPTION}_bin{current_bin_interval:.2f}m.csv'), index=False)

            # --- Summarize parameters ---
            desc = V.describe()
            print(desc)
            effective_range = desc.get('effective_range', np.nan)
            check_note = np.nan
            if not np.isnan(effective_range) and np.isclose(effective_range, maxlag):
                check_note = 'effective_range_eq_maxlag'

            # --- Normalize by maximum experimental semivariance ---
            max_gamma = np.max(semivars)
            nugget_normalized = desc.get('nugget', np.nan) / max_gamma if max_gamma > 0 else np.nan
            sill_normalized = desc.get('sill', np.nan) / max_gamma if max_gamma > 0 else np.nan

            overall_summary.append({
                'File Key_1': key,
                'nugget': desc.get('nugget', np.nan),
                'sill': desc.get('sill', np.nan),
                'effective_range': effective_range,
                'smoothness': desc.get('smoothness', np.nan),
                'nugget_normalized': nugget_normalized,
                'sill_normalized': sill_normalized,
                'maxlag': maxlag,
                'bin_interval_used': current_bin_interval,
                'WLS_option': WLS_OPTION,
                'Check': check_note
            })

            break  # Exit loop on successful fit

        except Exception as e:
            print(f"  Failed attempt {attempt+1} for {key} with bin_interval {current_bin_interval:.2f}m: {e}")
            current_bin_interval *= BIN_INTERVAL_MULTIPLIER
            if attempt == RETRY_ATTEMPTS - 1:
                overall_summary.append({
                    'File Key_1': key,
                    'nugget': np.nan,
                    'sill': np.nan,
                    'effective_range': np.nan,
                    'smoothness': np.nan,
                    'nugget_normalized': np.nan,
                    'sill_normalized': np.nan,
                    'maxlag': maxlag,
                    'bin_interval_used': current_bin_interval / BIN_INTERVAL_MULTIPLIER,
                    'WLS_option': WLS_OPTION,
                    'Check': 'Failed'
                })

# --- Save final summary ---
pd.DataFrame(overall_summary).to_csv(
    os.path.join(OUTPUT_BASE_FOLDER, f'variogram_parameters_summary_WLS_{WLS_OPTION}.csv'),
    index=False
)

print("\n--- Variogram analysis complete ---")
print(f"Results saved to the '{OUTPUT_BASE_FOLDER}' folder with WLS option '{WLS_OPTION}'.")
# Out:
# --- Processing File Key: 66983 ---
# /home/jki140/miniforge3/envs/Vs30/lib/python3.12/site-packages/skgstat/plotting/variogram_plot.py:123: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 59.86122253779583, 'normalized_sill': 0.05334540983268337, 'normalized_nugget': 0, 'effective_range': 6.651246948643982, 'sill': 0.22149660462344947, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.0034679 , 0.00365816, 0.00390002, 0.0041584 , 0.00443784,
#        0.00473547, 0.00505692, 0.00540261, 0.00577891, 0.0061775 ,
#        0.00661128, 0.00708021, 0.00758756, 0.00813779, 0.00873519,
#        0.00938479, 0.01010979, 0.010868  ]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 66984 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 29.460516129271568, 'normalized_sill': 0.07166781753004395, 'normalized_nugget': 0, 'effective_range': 3.273390681030174, 'sill': 0.23504721622322874, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.0034679 , 0.00365816, 0.00390002, 0.0041584 , 0.00443784,
#        0.00473547, 0.00505692, 0.00540261, 0.00577891, 0.0061775 ,
#        0.00661128, 0.00708021, 0.00758756, 0.00813779, 0.00873519,
#        0.00938479, 0.01010979, 0.010868  ]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 92524 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 51.2392018053292, 'normalized_sill': 0.008391036928991303, 'normalized_nugget': 0, 'effective_range': 5.693244645036578, 'sill': 0.0849635274694741, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00337984, 0.00356283, 0.00379561, 0.004044  , 0.00431219,
#        0.0045975 , 0.00490475, 0.00523499, 0.00559395, 0.00597343,
#        0.00638534, 0.00682959, 0.00730904, 0.00782756, 0.00838885,
#        0.00899717, 0.00967267, 0.01037807]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 92525 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 14.27356800973313, 'normalized_sill': 0.0015543057180497917, 'normalized_nugget': 0, 'effective_range': 1.427356800973313, 'sill': 0.0372080152724499, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00329737, 0.00347371, 0.00369822, 0.00393753, 0.00419551,
#        0.00446971, 0.00476452, 0.00508091, 0.0054237 , 0.00578613,
#        0.00617913, 0.00660166, 0.0070567 , 0.00754765, 0.00807774,
#        0.00865066, 0.00928409, 0.00994488, 0.01067519, 0.01146954]), 'use_nugget': False, 'maxlag': 10, 'n_lags': 20, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [9.5, 10])}}
#
# --- Processing File Key: 92526 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 45.49999999999999, 'normalized_sill': 0.011632772081053889, 'normalized_nugget': 0, 'effective_range': 6.499999999999999, 'sill': 0.07910608207168068, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.0037852 , 0.00400338, 0.00428011, 0.00457711, 0.00490054,
#        0.00524665, 0.00562268, 0.00603049, 0.00647858, 0.00695589,
#        0.00748086, 0.0080542 , 0.00868148, 0.00937035]), 'use_nugget': False, 'maxlag': 7, 'n_lags': 14, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [6.5, 10])}}
#
# --- Processing File Key: 92527 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 31.75782372572887, 'normalized_sill': 0.025400651471802, 'normalized_nugget': 0, 'effective_range': 3.528647080636541, 'sill': 0.14591096639197915, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00346882, 0.00365917, 0.00390112, 0.00415961, 0.00443917,
#        0.00473693, 0.00505853, 0.00540442, 0.00578084, 0.00617967,
#        0.00661369, 0.00708288, 0.00759054, 0.00814111, 0.00873891,
#        0.00938896, 0.01011451, 0.0108733 ]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 92534 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 82.71705089200432, 'normalized_sill': 0.007271506491751597, 'normalized_nugget': 0, 'effective_range': 6.3628500686157174, 'sill': 0.07533659613309238, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00288155, 0.00303024, 0.00321628, 0.00341366, 0.00362493,
#        0.00384885, 0.00408056, 0.00432224, 0.00459351, 0.00488007,
#        0.0051874 , 0.00551542, 0.00586566, 0.00623997, 0.00664008,
#        0.00706792, 0.0075326 , 0.00801676, 0.00854156, 0.00909491,
#        0.00970896, 0.01035728, 0.01105379, 0.01180266, 0.01260923,
#        0.01347786]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 92535 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 28.74972745273284, 'normalized_sill': 0.026891898681541473, 'normalized_nugget': 0, 'effective_range': 2.2115174963640647, 'sill': 0.1490946027455181, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00289616, 0.00304862, 0.00323547, 0.00343207, 0.00364436,
#        0.00387422, 0.00410497, 0.00435657, 0.00463129, 0.00492118,
#        0.00521251, 0.0055281 , 0.00587946, 0.00625103, 0.00665155,
#        0.00708042, 0.00754611, 0.0080317 , 0.00855839, 0.00912293,
#        0.00972863, 0.01037908, 0.01107756, 0.01182885, 0.01263813,
#        0.01350961]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 92536 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 21.3098342435482, 'normalized_sill': 0.03607205683818074, 'normalized_nugget': 0, 'effective_range': 2.663729280443525, 'sill': 0.16216730909961757, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00367015, 0.00387789, 0.00414189, 0.00442441, 0.00473128,
#        0.00505906, 0.0054142 , 0.00579827, 0.00621871, 0.0066656 ,
#        0.00715506, 0.00768744, 0.00826732, 0.00890092, 0.00959452,
#        0.01035561]), 'use_nugget': False, 'maxlag': 8, 'n_lags': 16, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [7.5, 10])}}
#
# --- Processing File Key: 92537 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 72.48969878867774, 'normalized_sill': 0.0045495285854922915, 'normalized_nugget': 0, 'effective_range': 5.177835627762696, 'sill': 0.05945302684306083, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00280118, 0.0029409 , 0.00311968, 0.00330931, 0.00351208,
#        0.0037266 , 0.00395547, 0.00419926, 0.00446067, 0.00473596,
#        0.00503094, 0.00534548, 0.0056809 , 0.00603892, 0.00642114,
#        0.00682929, 0.00727177, 0.00773242, 0.0082312 , 0.00876496,
#        0.00933649, 0.00994882, 0.01060531, 0.01130961, 0.01206547,
#        0.0128779 , 0.0137526 , 0.01469304]), 'use_nugget': False, 'maxlag': 14, 'n_lags': 28, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [13.5, 10])}}
#
# --- Processing File Key: 92538 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 100.15911738468174, 'normalized_sill': 0.009776224631160681, 'normalized_nugget': 0, 'effective_range': 7.7045474911293645, 'sill': 0.07939147073192308, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00290403, 0.0030509 , 0.00323862, 0.0034379 , 0.00365132,
#        0.00387729, 0.00411871, 0.00437621, 0.00465284, 0.00494434,
#        0.00525728, 0.00559151, 0.00594851, 0.00633027, 0.00673859,
#        0.00717547, 0.00765069, 0.00814541, 0.00868289, 0.00925953,
#        0.00987861, 0.01054379, 0.01125996, 0.01202996, 0.0128592 ,
#        0.01375388]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 92539 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 33.95779182261947, 'normalized_sill': 0.00629123398018573, 'normalized_nugget': 0, 'effective_range': 4.244723977827434, 'sill': 0.07500624291625506, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00356523, 0.00376377, 0.00401596, 0.00428573, 0.00457842,
#        0.00489025, 0.00522731, 0.00559097, 0.0059878 , 0.00640886,
#        0.00686842, 0.00736662, 0.00790729, 0.00849564, 0.00913681,
#        0.00983684]), 'use_nugget': False, 'maxlag': 8, 'n_lags': 16, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [7.5, 10])}}
#
# --- Processing File Key: 92540 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 10.347278835921692, 'normalized_sill': 0.0029131230753667134, 'normalized_nugget': 0, 'effective_range': 1.2934098544902115, 'sill': 0.04817602103233263, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00385034, 0.00411006, 0.00442027, 0.00473234, 0.00507933,
#        0.00545728, 0.00586286, 0.0062972 , 0.00672056, 0.00709641,
#        0.00755483, 0.00812168, 0.00872252, 0.00938988, 0.01013452,
#        0.01097285]), 'use_nugget': False, 'maxlag': 8, 'n_lags': 16, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [7.5, 10])}}
#
# --- Processing File Key: 92541 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 115.49999999999999, 'normalized_sill': 0.009387013829192752, 'normalized_nugget': 0, 'effective_range': 10.499999999999998, 'sill': 0.09402975256098321, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00318645, 0.00337382, 0.003601  , 0.00383139, 0.00408261,
#        0.00435226, 0.00463844, 0.00494169, 0.0052432 , 0.00552684,
#        0.00585455, 0.00623713, 0.00663935, 0.00707539, 0.00754883,
#        0.00806498, 0.00863092, 0.009223  , 0.00987092, 0.01057145,
#        0.01132963, 0.01215177]), 'use_nugget': False, 'maxlag': 11, 'n_lags': 22, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [10.5, 10])}}
#
# --- Processing File Key: 92542 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 52.56022585854018, 'normalized_sill': 0.009146384504655726, 'normalized_nugget': 0, 'effective_range': 4.043094296810783, 'sill': 0.08901407505262032, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00285121, 0.00299438, 0.00317748, 0.00337176, 0.00357967,
#        0.00379971, 0.00403462, 0.004285  , 0.00455372, 0.00483679,
#        0.00514038, 0.00546434, 0.00581009, 0.00617945, 0.00657412,
#        0.00699596, 0.00745402, 0.00793086, 0.008448  , 0.00900207,
#        0.00959608, 0.01023336, 0.01091755, 0.01165269, 0.01244386,
#        0.01329481]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 92543 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 49.80093768121702, 'normalized_sill': 0.005717260800224197, 'normalized_nugget': 0, 'effective_range': 5.533437520135225, 'sill': 0.06810815194316595, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00346882, 0.00365917, 0.00390112, 0.00415961, 0.00443917,
#        0.00473693, 0.00505853, 0.00540442, 0.00578084, 0.00617967,
#        0.00661369, 0.00708288, 0.00759054, 0.00814111, 0.00873891,
#        0.00938896, 0.01011451, 0.0108733 ]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 92544 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 21.303760077401773, 'normalized_sill': 0.0861680526250117, 'normalized_nugget': 0, 'effective_range': 3.0433942967716816, 'sill': 0.2608338869432189, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00469767, 0.00517873, 0.00567952, 0.00616705, 0.00672311,
#        0.00751268, 0.00827055, 0.00907157, 0.00968611, 0.01037383,
#        0.01126725, 0.01211573, 0.01307971, 0.01325268]), 'use_nugget': False, 'maxlag': 7, 'n_lags': 14, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [6.5, 10])}}
#
# --- Processing File Key: 92545 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 46.26869146484207, 'normalized_sill': 0.06371918104365529, 'normalized_nugget': 0, 'effective_range': 4.626869146484207, 'sill': 0.21502570704936846, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00329737, 0.00347371, 0.00369822, 0.00393753, 0.00419551,
#        0.00446971, 0.00476452, 0.00508091, 0.0054237 , 0.00578613,
#        0.00617913, 0.00660166, 0.0070567 , 0.00754765, 0.00807774,
#        0.00865066, 0.00928409, 0.00994488, 0.01067519, 0.01146954]), 'use_nugget': False, 'maxlag': 10, 'n_lags': 20, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [9.5, 10])}}
#
# --- Processing File Key: 92546 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 81.26783445174794, 'normalized_sill': 0.02475408632445016, 'normalized_nugget': 0, 'effective_range': 6.772319537645663, 'sill': 0.13655028396484487, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00301911, 0.00317425, 0.00337229, 0.00358275, 0.00380856,
#        0.00404787, 0.00430398, 0.00457759, 0.0048722 , 0.00518289,
#        0.0055172 , 0.00587496, 0.0062579 , 0.00666831, 0.00710831,
#        0.00758027, 0.00809576, 0.00863252, 0.00921888, 0.0098493 ,
#        0.01052851, 0.01126104, 0.01205198, 0.01290702]), 'use_nugget': False, 'maxlag': 12, 'n_lags': 24, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [11.5, 10])}}
#
# --- Processing File Key: 92547 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 85.4489685870242, 'normalized_sill': 0.009568157193345864, 'normalized_nugget': 0, 'effective_range': 6.103497756216014, 'sill': 0.08538354568620095, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00280118, 0.0029409 , 0.00311968, 0.00330931, 0.00351208,
#        0.0037266 , 0.00395547, 0.00419926, 0.00446067, 0.00473596,
#        0.00503094, 0.00534548, 0.0056809 , 0.00603892, 0.00642114,
#        0.00682929, 0.00727177, 0.00773242, 0.0082312 , 0.00876496,
#        0.00933649, 0.00994882, 0.01060531, 0.01130961, 0.01206547,
#        0.0128779 , 0.0137526 , 0.01469304]), 'use_nugget': False, 'maxlag': 14, 'n_lags': 28, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [13.5, 10])}}
#
# --- Processing File Key: 92548 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 10.514105531614957, 'normalized_sill': 0.008208641988451658, 'normalized_nugget': 0, 'effective_range': 1.502015075944994, 'sill': 0.08260739746027533, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00469767, 0.00517873, 0.00567952, 0.00616705, 0.00672311,
#        0.00751268, 0.00827055, 0.00907157, 0.00968611, 0.01037383,
#        0.01126725, 0.01211573, 0.01307971, 0.01325268]), 'use_nugget': False, 'maxlag': 7, 'n_lags': 14, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [6.5, 10])}}
#
# --- Processing File Key: 92549 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 50.173057725033885, 'normalized_sill': 0.025507467575642533, 'normalized_nugget': 0, 'effective_range': 5.017305772503389, 'sill': 0.1428335761637958, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00322065, 0.00339097, 0.00360795, 0.00383905, 0.00408782,
#        0.00435201, 0.00463567, 0.00493968, 0.00526846, 0.00561579,
#        0.00599125, 0.00639466, 0.00682882, 0.00729577, 0.00779886,
#        0.00834133, 0.00893887, 0.00956176, 0.01024745, 0.01099079]), 'use_nugget': False, 'maxlag': 10, 'n_lags': 20, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [9.5, 10])}}
#
# --- Processing File Key: 92554 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 66.30570669830091, 'normalized_sill': 0.025690144548601423, 'normalized_nugget': 0, 'effective_range': 7.367300744255656, 'sill': 0.1502678607656089, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.0035247 , 0.00371262, 0.00394561, 0.00419999, 0.00448341,
#        0.00478589, 0.00511257, 0.0054639 , 0.00584642, 0.00625256,
#        0.00669459, 0.00717286, 0.00769083, 0.00825336, 0.0088648 ,
#        0.00952994, 0.01027337, 0.01105297]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 92555 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 145.23015128331355, 'normalized_sill': 0.003012957759167259, 'normalized_nugget': 0, 'effective_range': 11.171550098716427, 'sill': 0.04576441535661587, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00285121, 0.00299438, 0.00317748, 0.00337176, 0.00357967,
#        0.00379971, 0.00403462, 0.004285  , 0.00455372, 0.00483679,
#        0.00514038, 0.00546434, 0.00581009, 0.00617945, 0.00657412,
#        0.00699596, 0.00745402, 0.00793086, 0.008448  , 0.00900207,
#        0.00959608, 0.01023336, 0.01091755, 0.01165269, 0.01244386,
#        0.01329481]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 92556 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 162.49999999999997, 'normalized_sill': 0.004906879712238468, 'normalized_nugget': 0, 'effective_range': 12.499999999999998, 'sill': 0.05134396972457906, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00290403, 0.0030509 , 0.00323862, 0.0034379 , 0.00365132,
#        0.00387729, 0.00411871, 0.00437621, 0.00465284, 0.00494434,
#        0.00525728, 0.00559151, 0.00594851, 0.00633027, 0.00673859,
#        0.00717547, 0.00765069, 0.00814541, 0.00868289, 0.00925953,
#        0.00987861, 0.01054379, 0.01125996, 0.01202996, 0.0128592 ,
#        0.01375388]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 92557 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 162.49999999999997, 'normalized_sill': 0.0035771933682185652, 'normalized_nugget': 0, 'effective_range': 12.499999999999998, 'sill': 0.051350411369382225, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00285121, 0.00299438, 0.00317748, 0.00337176, 0.00357967,
#        0.00379971, 0.00403462, 0.004285  , 0.00455372, 0.00483679,
#        0.00514038, 0.00546434, 0.00581009, 0.00617945, 0.00657412,
#        0.00699596, 0.00745402, 0.00793086, 0.008448  , 0.00900207,
#        0.00959608, 0.01023336, 0.01091755, 0.01165269, 0.01244386,
#        0.01329481]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 94658 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 76.49999999999999, 'normalized_sill': 0.007827985911310264, 'normalized_nugget': 0, 'effective_range': 8.499999999999998, 'sill': 0.07869799425578115, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00357567, 0.00378067, 0.00400157, 0.00426369, 0.00455297,
#        0.00486297, 0.00519763, 0.005558  , 0.00595045, 0.00636809,
#        0.00682304, 0.00731598, 0.00785064, 0.00843261, 0.00906582,
#        0.00975673, 0.01052913, 0.01134301]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 100703 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 27.648427764354857, 'normalized_sill': 0.0017672415086014957, 'normalized_nugget': 0, 'effective_range': 2.3040356470295715, 'sill': 0.039345225421637826, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00301789, 0.00317294, 0.00337087, 0.00358119, 0.0038069 ,
#        0.00404605, 0.004302  , 0.00457542, 0.00486988, 0.00518033,
#        0.00551441, 0.00587191, 0.00625456, 0.00666466, 0.00710431,
#        0.00757587, 0.00809092, 0.00862721, 0.00921302, 0.00984284,
#        0.01052137, 0.01125314, 0.01204321, 0.01289728]), 'use_nugget': False, 'maxlag': 12, 'n_lags': 24, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [11.5, 10])}}
#
# --- Processing File Key: 114319 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 16.37673892900533, 'normalized_sill': 0.0006804435192384536, 'normalized_nugget': 0, 'effective_range': 1.81963765877837, 'sill': 0.021014896273960294, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00338241, 0.00356561, 0.00379865, 0.00404738, 0.00431579,
#        0.00460151, 0.00490915, 0.00523983, 0.00559929, 0.00597932,
#        0.00639185, 0.0068368 , 0.00731704, 0.00783644, 0.00839874,
#        0.00900837, 0.00968493, 0.01039196]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 114322 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 76.49999999999999, 'normalized_sill': 0.00361026848485794, 'normalized_nugget': 0, 'effective_range': 8.499999999999998, 'sill': 0.05748584789574478, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00338241, 0.00356561, 0.00379865, 0.00404738, 0.00431579,
#        0.00460151, 0.00490915, 0.00523983, 0.00559929, 0.00597932,
#        0.00639185, 0.0068368 , 0.00731704, 0.00783644, 0.00839874,
#        0.00900837, 0.00968493, 0.01039196]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 122141 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 33.06741025667683, 'normalized_sill': 0.004292556602085952, 'normalized_nugget': 0, 'effective_range': 3.006128205152439, 'sill': 0.050845145082751134, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00314837, 0.00331313, 0.00352319, 0.00374672, 0.00398706,
#        0.00424209, 0.00451559, 0.00480834, 0.00512449, 0.00545818,
#        0.00581828, 0.00620461, 0.00661922, 0.00706484, 0.00754461,
#        0.00806033, 0.00862657, 0.00921652, 0.00986373, 0.01056339,
#        0.01132074, 0.01214174]), 'use_nugget': False, 'maxlag': 11, 'n_lags': 22, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [10.5, 10])}}
#
# --- Processing File Key: 123178 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 35.999602489261214, 'normalized_sill': 0.008176735249929533, 'normalized_nugget': 0, 'effective_range': 5.1428003556087445, 'sill': 0.08776028976578527, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00391007, 0.00413927, 0.00442987, 0.004744  , 0.00508402,
#        0.00545261, 0.00585278, 0.00628802, 0.00676229, 0.0072802 ,
#        0.00784711, 0.00846929, 0.00915417, 0.00991059]), 'use_nugget': False, 'maxlag': 7, 'n_lags': 14, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [6.5, 10])}}
#
# --- Processing File Key: 123208 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 87.27627382680072, 'normalized_sill': 0.002293738802649071, 'normalized_nugget': 0, 'effective_range': 7.934206711527338, 'sill': 0.04343157498467126, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00318243, 0.0033496 , 0.00356248, 0.00378994, 0.00403345,
#        0.00429341, 0.00457172, 0.00486971, 0.00519067, 0.00553141,
#        0.00589859, 0.00629279, 0.00671615, 0.00717201, 0.0076622 ,
#        0.00819028, 0.00876887, 0.00937585, 0.01004063, 0.01076018,
#        0.01154016, 0.01238697]), 'use_nugget': False, 'maxlag': 11, 'n_lags': 22, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [10.5, 10])}}
#
# --- Processing File Key: 124801 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 23.996594840819174, 'normalized_sill': 0.0005634983602720903, 'normalized_nugget': 0, 'effective_range': 2.666288315646575, 'sill': 0.019793705773133025, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00346882, 0.00365917, 0.00390112, 0.00415961, 0.00443917,
#        0.00473693, 0.00505853, 0.00540442, 0.00578084, 0.00617967,
#        0.00661369, 0.00708288, 0.00759054, 0.00814111, 0.00873891,
#        0.00938896, 0.01011451, 0.0108733 ]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 124802 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 19.260789751129348, 'normalized_sill': 0.0003729352287908368, 'normalized_nugget': 0, 'effective_range': 2.4075987188911685, 'sill': 0.01751102227061685, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00368722, 0.00389227, 0.00415774, 0.00444199, 0.0047506 ,
#        0.00508051, 0.005438  , 0.00582486, 0.00624811, 0.00669852,
#        0.00719192, 0.00772883, 0.00831391, 0.00895355, 0.00965419,
#        0.01042388]), 'use_nugget': False, 'maxlag': 8, 'n_lags': 16, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [7.5, 10])}}
#
# --- Processing File Key: 125043 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 45.49999999999999, 'normalized_sill': 0.05291475368346717, 'normalized_nugget': 0, 'effective_range': 6.499999999999999, 'sill': 0.20149510709862958, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00388672, 0.00412331, 0.00441395, 0.00472529, 0.00505471,
#        0.00537588, 0.00575996, 0.00618434, 0.00665035, 0.00714939,
#        0.00769947, 0.00830125, 0.00896199, 0.00969035]), 'use_nugget': False, 'maxlag': 7, 'n_lags': 14, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [6.5, 10])}}
#
# --- Processing File Key: 126232 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 66.84726034315366, 'normalized_sill': 0.010141787596838118, 'normalized_nugget': 0, 'effective_range': 5.570605028596138, 'sill': 0.08410486838541809, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.0030472 , 0.00320452, 0.00340619, 0.00361963, 0.00384841,
#        0.00409133, 0.00434606, 0.00461485, 0.00490654, 0.00522045,
#        0.00555818, 0.00591975, 0.00630689, 0.00672196, 0.00716714,
#        0.00764502, 0.00816662, 0.00871067, 0.00930503, 0.00994441,
#        0.01063368, 0.01137754, 0.01218127, 0.01305091]), 'use_nugget': False, 'maxlag': 12, 'n_lags': 24, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [11.5, 10])}}
#
# --- Processing File Key: 128450 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 115.49999999999999, 'normalized_sill': 0.021010829814254214, 'normalized_nugget': 0, 'effective_range': 10.499999999999998, 'sill': 0.1274022179071227, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00325122, 0.00346639, 0.003708  , 0.00394689, 0.00419296,
#        0.00445326, 0.00469555, 0.00496327, 0.00529322, 0.00564389,
#        0.00602169, 0.00640563, 0.00683917, 0.0073072 , 0.00781213,
#        0.00835601, 0.00895438, 0.00957987, 0.01026763, 0.01101332,
#        0.01182322, 0.01270422]), 'use_nugget': False, 'maxlag': 11, 'n_lags': 22, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [10.5, 10])}}
#
# --- Processing File Key: 136515 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 49.678822008015075, 'normalized_sill': 0.0012899631821234538, 'normalized_nugget': 0, 'effective_range': 5.519869112001675, 'sill': 0.03556442275779068, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00349163, 0.00368552, 0.00393008, 0.00419133, 0.00447406,
#        0.00477531, 0.00510083, 0.00545112, 0.00581791, 0.00620812,
#        0.00664521, 0.00711792, 0.00762958, 0.00818497, 0.00878771,
#        0.00944375, 0.01017613, 0.01094303]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 139896 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 39.018073105313576, 'normalized_sill': 0.06470562714343846, 'normalized_nugget': 0, 'effective_range': 3.5470975550285067, 'sill': 0.22996219501486614, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00314906, 0.00331387, 0.003524  , 0.0037476 , 0.00398802,
#        0.00424314, 0.00451674, 0.00480961, 0.00512583, 0.00545967,
#        0.00581992, 0.00620641, 0.0066212 , 0.00706702, 0.00754701,
#        0.00806297, 0.00862951, 0.00921976, 0.00986732, 0.01056738,
#        0.01132518, 0.0121467 ]), 'use_nugget': False, 'maxlag': 11, 'n_lags': 22, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [10.5, 10])}}
#
# --- Processing File Key: 139897 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 14.987956371715434, 'normalized_sill': 0.10389636567722546, 'normalized_nugget': 0, 'effective_range': 2.1411366245307764, 'sill': 0.2904613059420526, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00391321, 0.004143  , 0.00443477, 0.00474859, 0.00509137,
#        0.00545902, 0.00585976, 0.00629591, 0.00677711, 0.0072913 ,
#        0.00785969, 0.0084836 , 0.0091701 , 0.00992888]), 'use_nugget': False, 'maxlag': 7, 'n_lags': 14, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [6.5, 10])}}
#
# --- Processing File Key: 140250 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 59.99999999999999, 'normalized_sill': 0.035578907913501594, 'normalized_nugget': 0, 'effective_range': 7.499999999999999, 'sill': 0.1901365113847039, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00356523, 0.00376377, 0.00401596, 0.00428573, 0.00457842,
#        0.00489025, 0.00522731, 0.00559097, 0.0059878 , 0.00640886,
#        0.00686842, 0.00736662, 0.00790729, 0.00849564, 0.00913681,
#        0.00983684]), 'use_nugget': False, 'maxlag': 8, 'n_lags': 16, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [7.5, 10])}}
#
# --- Processing File Key: 140251 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 35.98669880985151, 'normalized_sill': 0.01145604330393934, 'normalized_nugget': 0, 'effective_range': 3.998522089983501, 'sill': 0.10007954511527746, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00337984, 0.00356283, 0.00379561, 0.004044  , 0.00431219,
#        0.0045975 , 0.00490475, 0.00523499, 0.00559395, 0.00597343,
#        0.00638534, 0.00682959, 0.00730904, 0.00782756, 0.00838885,
#        0.00899717, 0.00967267, 0.01037807]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 140253 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 59.99999999999999, 'normalized_sill': 0.2530922053503589, 'normalized_nugget': 0, 'effective_range': 7.499999999999999, 'sill': 0.47970241814221626, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00367015, 0.00387789, 0.00414189, 0.00442441, 0.00473128,
#        0.00505906, 0.0054142 , 0.00579827, 0.00621871, 0.0066656 ,
#        0.00715506, 0.00768744, 0.00826732, 0.00890092, 0.00959452,
#        0.01035561]), 'use_nugget': False, 'maxlag': 8, 'n_lags': 16, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [7.5, 10])}}
#
# --- Processing File Key: 140254 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 29.591404456515214, 'normalized_sill': 0.013350245999654207, 'normalized_nugget': 0, 'effective_range': 2.6901276778650196, 'sill': 0.10042870815981064, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00314906, 0.00331387, 0.003524  , 0.0037476 , 0.00398802,
#        0.00424314, 0.00451674, 0.00480961, 0.00512583, 0.00545967,
#        0.00581992, 0.00620641, 0.0066212 , 0.00706702, 0.00754701,
#        0.00806297, 0.00862951, 0.00921976, 0.00986732, 0.01056738,
#        0.01132518, 0.0121467 ]), 'use_nugget': False, 'maxlag': 11, 'n_lags': 22, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [10.5, 10])}}
#
# --- Processing File Key: 140257 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 27.85931878187806, 'normalized_sill': 0.004063671353356656, 'normalized_nugget': 0, 'effective_range': 2.5326653438070963, 'sill': 0.0591599950480192, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00308203, 0.00324181, 0.00344564, 0.0036624 , 0.00389519,
#        0.00414206, 0.00440651, 0.0046893 , 0.00499419, 0.00531588,
#        0.0056625 , 0.00603387, 0.00643187, 0.00685899, 0.00731755,
#        0.00781017, 0.00835019, 0.00891201, 0.00952659, 0.01018941,
#        0.01090508, 0.01167876]), 'use_nugget': False, 'maxlag': 11, 'n_lags': 22, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [10.5, 10])}}
#
# --- Processing File Key: 140260 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 32.958457133798525, 'normalized_sill': 0.058215564796695804, 'normalized_nugget': 0, 'effective_range': 3.6620507926442802, 'sill': 0.2143087235318636, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00346882, 0.00365917, 0.00390112, 0.00415961, 0.00443917,
#        0.00473693, 0.00505853, 0.00540442, 0.00578084, 0.00617967,
#        0.00661369, 0.00708288, 0.00759054, 0.00814111, 0.00873891,
#        0.00938896, 0.01011451, 0.0108733 ]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 140262 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 17.114966884635145, 'normalized_sill': 0.07142744604400053, 'normalized_nugget': 0, 'effective_range': 2.444995269233592, 'sill': 0.23381104792405957, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00391148, 0.00414154, 0.00443316, 0.00474679, 0.00508937,
#        0.00545679, 0.00585727, 0.00629305, 0.00677401, 0.00728774,
#        0.00785565, 0.00847901, 0.00916485, 0.00992285]), 'use_nugget': False, 'maxlag': 7, 'n_lags': 14, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [6.5, 10])}}
#
# --- Processing File Key: 140263 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 94.99999999999999, 'normalized_sill': 0.0033786642089043977, 'normalized_nugget': 0, 'effective_range': 9.499999999999998, 'sill': 0.0510765108449752, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00329737, 0.00347371, 0.00369822, 0.00393753, 0.00419551,
#        0.00446971, 0.00476452, 0.00508091, 0.0054237 , 0.00578613,
#        0.00617913, 0.00660166, 0.0070567 , 0.00754765, 0.00807774,
#        0.00865066, 0.00928409, 0.00994488, 0.01067519, 0.01146954]), 'use_nugget': False, 'maxlag': 10, 'n_lags': 20, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [9.5, 10])}}
#
# --- Processing File Key: 141748 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 14.759724315170388, 'normalized_sill': 0.006846582101775797, 'normalized_nugget': 0, 'effective_range': 1.8449655393962985, 'sill': 0.07229875527518413, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00356322, 0.00376159, 0.00401356, 0.00428307, 0.00457554,
#        0.00488704, 0.00522377, 0.00558701, 0.00598348, 0.00640402,
#        0.00686304, 0.00736061, 0.00790057, 0.00848809, 0.00912831,
#        0.00982725]), 'use_nugget': False, 'maxlag': 8, 'n_lags': 16, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [7.5, 10])}}
#
# --- Processing File Key: 148992 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 27.30799975085673, 'normalized_sill': 0.016593990402337132, 'normalized_nugget': 0, 'effective_range': 2.4825454318960665, 'sill': 0.11566129550896662, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00312167, 0.00328607, 0.00349676, 0.00371799, 0.0039557 ,
#        0.00420795, 0.00447834, 0.0047678 , 0.00507973, 0.00540948,
#        0.00576494, 0.0061461 , 0.006555  , 0.00699418, 0.00746622,
#        0.00793935, 0.00845525, 0.00901316, 0.00963845, 0.01031333,
#        0.01104262, 0.01183174]), 'use_nugget': False, 'maxlag': 11, 'n_lags': 22, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [10.5, 10])}}
#
# --- Processing File Key: 148995 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 51.98083931189006, 'normalized_sill': 0.02423718667320051, 'normalized_nugget': 0, 'effective_range': 3.99852610091462, 'sill': 0.14286134163399886, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00290512, 0.00305206, 0.00323988, 0.00343928, 0.00365279,
#        0.00387889, 0.00412045, 0.00437809, 0.00465489, 0.00494657,
#        0.0052597 , 0.00559414, 0.00595138, 0.0063334 , 0.006742  ,
#        0.00717928, 0.0076547 , 0.00814988, 0.00868779, 0.0092649 ,
#        0.00988452, 0.01055029, 0.01126712, 0.01203787, 0.01286794,
#        0.01376355]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 148998 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 27.594496907258517, 'normalized_sill': 0.02054877131027556, 'normalized_nugget': 0, 'effective_range': 2.5085906279325925, 'sill': 0.12472139352412635, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00308333, 0.0032432 , 0.00344715, 0.00366406, 0.00389697,
#        0.00414401, 0.00440864, 0.00469162, 0.00499673, 0.00531865,
#        0.00566553, 0.00603718, 0.00643549, 0.00686297, 0.00732193,
#        0.00781508, 0.0083554 , 0.00891787, 0.00953306, 0.01019658,
#        0.01091303, 0.01168759]), 'use_nugget': False, 'maxlag': 11, 'n_lags': 22, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [10.5, 10])}}
#
# --- Processing File Key: 148999 ---
# ...
#
# --- Processing File Key: 178944 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 15.48796793121578, 'normalized_sill': 0.020479917703164617, 'normalized_nugget': 0, 'effective_range': 2.21256684731654, 'sill': 0.1333135634824956, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00378761, 0.004006  , 0.00428301, 0.00458036, 0.00490408,
#        0.00525062, 0.0056271 , 0.00603542, 0.00648412, 0.00696209,
#        0.00748784, 0.00806208, 0.00869041, 0.00938051]), 'use_nugget': False, 'maxlag': 7, 'n_lags': 14, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [6.5, 10])}}
#
# --- Processing File Key: 178947 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 76.49999999999994, 'normalized_sill': 0.08268036245791775, 'normalized_nugget': 0, 'effective_range': 8.499999999999993, 'sill': 0.2380202538128679, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00347068, 0.00366117, 0.00390332, 0.00416205, 0.0044418 ,
#        0.00473985, 0.00506174, 0.00540797, 0.00578477, 0.00618401,
#        0.00661851, 0.00708824, 0.00759651, 0.00814777, 0.00874637,
#        0.0093975 , 0.01012379, 0.01088395]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 183366 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 25.68455412005058, 'normalized_sill': 0.012835069216239479, 'normalized_nugget': 0, 'effective_range': 2.3349594654591437, 'sill': 0.10083838670131598, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00308726, 0.00324737, 0.00345172, 0.00366907, 0.00390231,
#        0.00414988, 0.00441503, 0.00469864, 0.0050043 , 0.00532697,
#        0.00567463, 0.00604715, 0.00644642, 0.00687496, 0.0073351 ,
#        0.00782957, 0.00837143, 0.00893551, 0.00955256, 0.01021817,
#        0.01093698, 0.01171422]), 'use_nugget': False, 'maxlag': 11, 'n_lags': 22, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [10.5, 10])}}
#
# --- Processing File Key: 184148 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 19.627872998634178, 'normalized_sill': 0.0009174229289794687, 'normalized_nugget': 0, 'effective_range': 2.18087477762602, 'sill': 0.02878934053940799, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00337813, 0.00356098, 0.00379358, 0.00404177, 0.00430978,
#        0.00459484, 0.00490182, 0.00523174, 0.00559043, 0.00596952,
#        0.00638101, 0.0068248 , 0.00730373, 0.00782165, 0.00838227,
#        0.00898983, 0.00966441, 0.01036885]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 192457 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 23.57366367141589, 'normalized_sill': 0.011630751158030103, 'normalized_nugget': 0, 'effective_range': 1.6838331193868492, 'sill': 0.08373984769717356, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00282509, 0.00296632, 0.00314687, 0.00333897, 0.00354367,
#        0.00376125, 0.00399303, 0.00423994, 0.00450413, 0.00478357,
#        0.00508259, 0.00540156, 0.00574182, 0.00610545, 0.00649353,
#        0.00690819, 0.0073564 , 0.00782579, 0.00833316, 0.0088764 ,
#        0.00945843, 0.0100824 , 0.0107518 , 0.01147045, 0.0122423 ,
#        0.01307257, 0.01396619, 0.01492891]), 'use_nugget': False, 'maxlag': 14, 'n_lags': 28, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [13.5, 10])}}
#
# --- Processing File Key: 192465 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 21.2477474794464, 'normalized_sill': 0.0011225476786944188, 'normalized_nugget': 0, 'effective_range': 1.6344421138035692, 'sill': 0.02905969185634339, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00285019, 0.00299328, 0.0031763 , 0.00337047, 0.0035783 ,
#        0.0037982 , 0.00403299, 0.00428321, 0.00455182, 0.00483471,
#        0.00513812, 0.00546189, 0.00580742, 0.00617655, 0.00657095,
#        0.00699251, 0.00745024, 0.00792674, 0.0084435 , 0.00899714,
#        0.00959068, 0.01022743, 0.01091103, 0.01164552, 0.01243596,
#        0.0132861 ]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 192469 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 77.32451998480289, 'normalized_sill': 0.005958429025846639, 'normalized_nugget': 0, 'effective_range': 5.523179998914492, 'sill': 0.06941541384939154, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00275276, 0.00288919, 0.00306386, 0.00324903, 0.00344695,
#        0.00365622, 0.00387936, 0.00411689, 0.00437142, 0.00463935,
#        0.00492622, 0.00523189, 0.00555762, 0.00590503, 0.0062756 ,
#        0.00667098, 0.007099  , 0.00754462, 0.0080264 , 0.00854143,
#        0.00909227, 0.00968174, 0.01031291, 0.01098913, 0.01171381,
#        0.01249152, 0.01332645, 0.01422352]), 'use_nugget': False, 'maxlag': 14, 'n_lags': 28, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [13.5, 10])}}
#
# --- Processing File Key: 192473 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 57.10512038674834, 'normalized_sill': 0.0032873450629153493, 'normalized_nugget': 0, 'effective_range': 4.758760032229028, 'sill': 0.04337978721024484, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00295875, 0.00310951, 0.00330209, 0.00350662, 0.0037259 ,
#        0.00395812, 0.00420644, 0.00447147, 0.00475657, 0.00505702,
#        0.00537995, 0.00572515, 0.00609424, 0.00648933, 0.00691236,
#        0.00736551, 0.00785935, 0.00837351, 0.0089332 , 0.00953454,
#        0.01018196, 0.01087802, 0.01162791, 0.01243664]), 'use_nugget': False, 'maxlag': 12, 'n_lags': 24, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [11.5, 10])}}
#
# --- Processing File Key: 192478 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 41.429724846467636, 'normalized_sill': 0.013967263781614008, 'normalized_nugget': 0, 'effective_range': 5.1787156058084545, 'sill': 0.11083348269358291, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00366796, 0.0038755 , 0.00413926, 0.00442149, 0.0047281 ,
#        0.00505551, 0.00541026, 0.00579385, 0.00621388, 0.00666015,
#        0.00714897, 0.00768061, 0.00825963, 0.00889224, 0.00958468,
#        0.01034442]), 'use_nugget': False, 'maxlag': 8, 'n_lags': 16, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [7.5, 10])}}
#
# --- Processing File Key: 192480 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 85.57875140459207, 'normalized_sill': 0.0026457087836152713, 'normalized_nugget': 0, 'effective_range': 6.582980877276313, 'sill': 0.044220625641522585, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00285019, 0.00299328, 0.0031763 , 0.00337047, 0.0035783 ,
#        0.0037982 , 0.00403299, 0.00428321, 0.00455182, 0.00483471,
#        0.00513812, 0.00546189, 0.00580742, 0.00617655, 0.00657095,
#        0.00699251, 0.00745024, 0.00792674, 0.0084435 , 0.00899714,
#        0.00959068, 0.01022743, 0.01091103, 0.01164552, 0.01243596,
#        0.0132861 ]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 192483 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 95.81841344242243, 'normalized_sill': 0.0029425827804511052, 'normalized_nugget': 0, 'effective_range': 7.370647187878649, 'sill': 0.05078327649030408, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00285019, 0.00299328, 0.0031763 , 0.00337047, 0.0035783 ,
#        0.0037982 , 0.00403299, 0.00428321, 0.00455182, 0.00483471,
#        0.00513812, 0.00546189, 0.00580742, 0.00617655, 0.00657095,
#        0.00699251, 0.00745024, 0.00792674, 0.0084435 , 0.00899714,
#        0.00959068, 0.01022743, 0.01091103, 0.01164552, 0.01243596,
#        0.0132861 ]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 195188 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 48.346480237760545, 'normalized_sill': 0.022272958227363894, 'normalized_nugget': 0, 'effective_range': 5.371831137528949, 'sill': 0.13618254040533329, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00346697, 0.00365716, 0.00389893, 0.00415717, 0.00443655,
#        0.00473402, 0.00505532, 0.00540084, 0.00577695, 0.00617533,
#        0.00660888, 0.00707754, 0.00758459, 0.00813447, 0.00873147,
#        0.00938062, 0.01010508, 0.0108627 ]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 195941 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 76.49999999999999, 'normalized_sill': 0.031691503366885955, 'normalized_nugget': 0, 'effective_range': 8.499999999999998, 'sill': 0.15878055008085676, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00337813, 0.00356098, 0.00379358, 0.00404177, 0.00430978,
#        0.00459484, 0.00490182, 0.00523174, 0.00559043, 0.00596952,
#        0.00638101, 0.0068248 , 0.00730373, 0.00782165, 0.00838227,
#        0.00898983, 0.00966441, 0.01036885]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Processing File Key: 196093 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 162.49999999999997, 'normalized_sill': 0.001029575281021193, 'normalized_nugget': 0, 'effective_range': 12.499999999999998, 'sill': 0.021806344306487993, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.0029307 , 0.00307931, 0.00326907, 0.0034712 , 0.00368685,
#        0.00391635, 0.00416117, 0.0044223 , 0.00470223, 0.00499858,
#        0.0053163 , 0.00565578, 0.00601857, 0.00640702, 0.0068224 ,
#        0.00726715, 0.00774943, 0.00825477, 0.00880283, 0.00939121,
#        0.01002339, 0.01070319, 0.01143485, 0.01222309, 0.01307391,
#        0.01399181]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 205817 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 18.95614235151262, 'normalized_sill': 0.01587921082616221, 'normalized_nugget': 0, 'effective_range': 1.4581647962702016, 'sill': 0.10213663528366815, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00290512, 0.00305206, 0.00323988, 0.00343926, 0.00365281,
#        0.00387889, 0.00412045, 0.00437809, 0.00465489, 0.00494657,
#        0.0052597 , 0.0055933 , 0.00594995, 0.00633184, 0.0067403 ,
#        0.00717733, 0.00765269, 0.00814764, 0.00868534, 0.00926221,
#        0.00988156, 0.01054704, 0.01126354, 0.01203391, 0.01286357,
#        0.01375871]), 'use_nugget': False, 'maxlag': 13, 'n_lags': 26, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [12.5, 10])}}
#
# --- Processing File Key: 205818 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 20.197756387372785, 'normalized_sill': 0.0028052642292244216, 'normalized_nugget': 0, 'effective_range': 1.4426968848123418, 'sill': 0.04783510550968036, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00275369, 0.00289018, 0.00306493, 0.00325018, 0.00344796,
#        0.00365689, 0.00388009, 0.00411767, 0.00437227, 0.00464027,
#        0.00492722, 0.00523297, 0.00555879, 0.0059063 , 0.00627698,
#        0.00667248, 0.00710064, 0.00754639, 0.00802833, 0.00854354,
#        0.00909458, 0.00968426, 0.01031566, 0.01099214, 0.01171711,
#        0.01249514, 0.01333043, 0.0142279 ]), 'use_nugget': False, 'maxlag': 14, 'n_lags': 28, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [13.5, 10])}}
#
# --- Processing File Key: 217000 ---
# {'model': 'exponential', 'estimator': 'matheron', 'dist_func': 'euclidean', 'normalized_effective_range': 17.98110123775467, 'normalized_sill': 0.00010561430016995375, 'normalized_nugget': 0, 'effective_range': 1.9979001375282968, 'sill': 0.010000000000000002, 'nugget': 0, 'params': {'estimator': 'matheron', 'model': 'exponential', 'dist_func': 'euclidean', 'bin_func': 'even', 'normalize': True, 'fit_method': 'trf', 'fit_sigma': array([0.00338155, 0.00356468, 0.00379763, 0.00404624, 0.0043146 ,
#        0.00460017, 0.00490768, 0.00523821, 0.00559751, 0.00597736,
#        0.00638968, 0.00683439, 0.00731437, 0.00783348, 0.00839544,
#        0.00900468, 0.00968078, 0.01038732]), 'use_nugget': False, 'maxlag': 9, 'n_lags': 18, 'verbose': False}, 'kwargs': {'fit_sill': True, 'fit_range': True, 'fit_bounds': ([0.5, 0.01], [8.5, 10])}}
#
# --- Variogram analysis complete ---
# Results saved to the 'variogram_model_fit_simple_exponential_exp' folder with WLS option 'exp'.

# %%
# -----------------------------------------------------------------------------
# Part 2: Load summary and plot fitted variogram curves from parameters
# -----------------------------------------------------------------------------

def exponential_variogram_func(h, nugget, sill, effective_range):
    """
    y = nugget + (sill - nugget) * (1 - exp(-h/a)), where a is the range parameter.
    This function now assumes normalized nugget and sill values.
    """
    partial_sill = sill - nugget

    # The range parameter 'a' is effective_range / 3 for the exponential model
    a = effective_range / 3

    if isinstance(h, (np.ndarray, list)):
        h = np.array(h)
        if np.isclose(a, 0):
            fitted_curve = np.full_like(h, sill)
        else:
            fitted_curve = nugget + partial_sill * (1 - np.exp(-h / a))

        fitted_curve[h == 0] = nugget

        return fitted_curve
    else:
        if np.isclose(h, 0):
            return nugget
        if np.isclose(a, 0):
            return sill
        return nugget + partial_sill * (1 - np.exp(-h / a))

# Use the correct summary file path from our previous conversation,
# which includes the 'Check' column.
SUMMARY_PATH = 'variogram_model_fit_simple_exponential_exp/variogram_parameters_summary_WLS_exp.csv'

if not os.path.exists(SUMMARY_PATH):
    print(f"Error: The summary file '{SUMMARY_PATH}' was not found.")
else:
    summary = pd.read_csv(SUMMARY_PATH)

    if 'maxlag' not in summary.columns:
        print("Error: 'maxlag' column not found in the summary file. Please run the previous script to include it.")
        exit()

    # Check for 'sill_normalized' and 'nugget_normalized' columns
    if 'sill_normalized' not in summary.columns:
        print("Warning: 'sill_normalized' column not found. Calculating it now.")

        # This requires the original data to get the variance for normalization
        # We'll assume the variance is a good approximation of the sill if not normalized.
        # It's better to add the calculation to the first part of the script.
        # For now, we'll try to approximate it.
        # A more robust solution is to re-run the first script after adding 'var_val' to the summary.

        # As a temporary workaround, we'll just use the raw sill and nugget, and the plot won't be normalized.
        # We will add a note to the user.
        print("The plot will not be normalized as required data is missing. Please ensure the 'sill_normalized' and 'nugget_normalized' columns are in the summary file.")

        # Filter for valid models using the 'Check' column.
        valid_models = summary[summary['Check'].isna()]

        # Calculate counts
        removed = len(summary) - len(valid_models)
        kept = len(valid_models)
        total = len(summary)

        plt.figure(figsize=(8, 5))

        if not valid_models.empty:
            max_x_plot = max(valid_models['effective_range'].max() * 1.2, valid_models['maxlag'].max())
            if pd.isna(max_x_plot):
                max_x_plot = 50

            for index, row in valid_models.iterrows():
                nugget = row['nugget']
                sill = row['sill_normalized']
                effective_range = row['effective_range']
                maxlag_for_curve = row['maxlag']
                lag_dense_individual = np.arange(0, maxlag_for_curve + 0.1, 0.02)
                fitted_curve = [exponential_variogram_func(h, nugget, sill, effective_range) for h in lag_dense_individual]
                plt.plot(lag_dense_individual, fitted_curve, linewidth=3, alpha=0.8)

    else:
        # This is the correct path for a normalized plot
        valid_models = summary[summary['Check'].isna()]
        removed = len(summary) - len(valid_models)
        kept = len(valid_models)
        total = len(summary)

        plt.figure(figsize=(8, 5))

        if not valid_models.empty:
            max_x_plot = max(valid_models['effective_range'].max() * 1.2, valid_models['maxlag'].max())
            if pd.isna(max_x_plot):
                max_x_plot = 50

            for index, row in valid_models.iterrows():
                nugget = row['nugget_normalized'] if 'nugget_normalized' in row else 0 # Use 0 if not available
                sill = row['sill_normalized']
                effective_range = row['effective_range']
                maxlag_for_curve = row['maxlag']
                lag_dense_individual = np.arange(0, maxlag_for_curve + 0.1, 0.02)
                fitted_curve = [exponential_variogram_func(h, nugget, sill, effective_range) for h in lag_dense_individual]
                plt.plot(lag_dense_individual, fitted_curve, linewidth=3, alpha=0.8)

        plt.ylim(0, 1.2) # Set y-axis to be 0-1.2 for normalized view

    print(f"\n--- Part 2 Finished ---")
    print(f"Total results: {total}")
    print(f"Number of results removed: {removed}")
    print(f"Number of results plotted: {kept}")

    plt.xlabel('Lag (m)')
    plt.ylabel('Fitted_Semivariance (normalized)')
    plt.title('Fitted Exponential Variogram Curves: All (filtered)')
    plt.grid(True)
    plt.show()
# Out:
# --- Part 2 Finished ---
# Total results: 90
# Number of results removed: 0
# Number of results plotted: 90

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from skgstat import Variogram
from scipy.optimize import curve_fit

# -----------------------------------------------------------------------------
# Exponential variogram functions
# -----------------------------------------------------------------------------
def exponential_variogram_func(h, nugget, sill, effective_range):
    """
    Exponential variogram model with nugget parameter.
    y = nugget + (sill - nugget) * (1 - exp(-h / (effective_range/3)))
    """
    partial_sill = sill - nugget
    a = effective_range / 3

    h = np.array(h)
    if np.isclose(a, 0):
        fitted_curve = np.full_like(h, sill)
    else:
        fitted_curve = nugget + partial_sill * (1 - np.exp(-h / a))
    fitted_curve[h == 0] = nugget
    return fitted_curve

def exponential_variogram_func_fixed_nugget(h, sill, effective_range):
    """
    Exponential variogram with nugget fixed at 0.
    y = 0 + sill * (1 - exp(-h / (effective_range/3)))
    """
    a = effective_range / 3
    h = np.array(h)
    fitted_curve = sill * (1 - np.exp(-h / a))
    fitted_curve[h == 0] = 0.0
    return fitted_curve

# -----------------------------------------------------------------------------
# Part 2: Load summary and generate individual fitted curves
# -----------------------------------------------------------------------------
SUMMARY_PATH = 'variogram_model_fit_simple_exponential_exp/variogram_parameters_summary_WLS_exp.csv'

if not os.path.exists(SUMMARY_PATH):
    print(f"Error: The summary file '{SUMMARY_PATH}' was not found.")
    exit()

summary = pd.read_csv(SUMMARY_PATH)
if 'maxlag' not in summary.columns:
    print("Error: 'maxlag' column not found in the summary file.")
    exit()

# Filter valid models (optional)
valid_summary = summary
removed = len(summary) - len(valid_summary)
kept = len(valid_summary)
total = len(summary)

nuggets = valid_summary['nugget'].values
sills = valid_summary['sill_normalized'].values
ranges = valid_summary['effective_range'].values
maxlags = valid_summary['maxlag'].values

if len(sills) == 0:
    print("No valid variogram models found to plot.")
    exit()

# --- Generate points from individual fitted curves ---
all_generated_lags = []
all_generated_semivariances = []

plt.figure(figsize=(8, 5))

for n, s, r, ml in zip(nuggets, sills, ranges, maxlags):
    lag_grid_individual = np.arange(0, ml + 0.1, 0.1)
    fitted_curve = exponential_variogram_func(lag_grid_individual, n, s, r)
    plt.plot(lag_grid_individual, fitted_curve, color='grey', alpha=0.2)
    all_generated_lags.extend(lag_grid_individual)
    all_generated_semivariances.extend(fitted_curve)

all_generated_lags = np.array(all_generated_lags)
all_generated_semivariances = np.array(all_generated_semivariances)

# -----------------------------------------------------------------------------
# Part 3: Unified curve fit with nugget fixed at 0
# -----------------------------------------------------------------------------
initial_guess = [np.mean(sills), np.mean(ranges)]
bounds_lower = [0.0, 0.0]
bounds_upper = [np.inf, np.inf]

try:
    popt_unified, pcov_unified = curve_fit(
        exponential_variogram_func_fixed_nugget,
        all_generated_lags,
        all_generated_semivariances,
        p0=initial_guess,
        bounds=(bounds_lower, bounds_upper)
    )
    unified_sill, unified_range = popt_unified
    perr_unified = np.sqrt(np.diag(pcov_unified))
    unified_sill_err, unified_range_err = perr_unified

except RuntimeError as e:
    print(f"Error: Unified curve fit failed. {e}")
    exit()

# Plot unified curve
max_lag_unified = np.max(maxlags)
lag_grid_dense = np.arange(0, max_lag_unified + 0.1, 0.1)
unified_curve = exponential_variogram_func_fixed_nugget(lag_grid_dense, unified_sill, unified_range)
plt.plot(lag_grid_dense, unified_curve, color='red', linewidth=3, label='Unified Exponential Model Fit (Nugget=0)')

# ±1 std dev shading
lower_bound_curve = exponential_variogram_func_fixed_nugget(
    lag_grid_dense,
    unified_sill - unified_sill_err,
    unified_range - unified_range_err
)
upper_bound_curve = exponential_variogram_func_fixed_nugget(
    lag_grid_dense,
    unified_sill + unified_sill_err,
    unified_range + unified_range_err
)
plt.fill_between(lag_grid_dense, lower_bound_curve, upper_bound_curve, color='red', alpha=0.3)

# Final plot adjustments
plt.xlabel('Lag (m)')
plt.ylabel('Semivariance')
plt.title('Individual Variogram Fits and Unified Exponential Model (Nugget=0)')
plt.grid(True)
plt.style.use('default')
plt.legend()
plt.ylim(0,1.2)
plt.tight_layout()
plt.savefig('unified_exponential_model_fit_nugget0.png')
plt.show()

# Print results
print("\n--- Part 2 Finished ---")
print(f"Total results: {total}")
print(f"Number of results removed: {removed}")
print(f"Number of results plotted: {kept}")
print("\nUnified Exponential Model Parameters (Nugget fixed at 0):")
print(f"  Nugget: 0.0000 (fixed)")
print(f"  Sill  : {unified_sill:.4f} ± {unified_sill_err:.4f}")
print(f"  Range : {unified_range:.4f} ± {unified_range_err:.4f}")
# Out:
# --- Part 2 Finished ---
# Total results: 90
# Number of results removed: 0
# Number of results plotted: 90
#
# Unified Exponential Model Parameters (Nugget fixed at 0):
#   Nugget: 0.0000 (fixed)
#   Sill  : 0.7599 ± 0.0019
#   Range : 4.3636 ± 0.0513
